# %% [markdown]
# # CNN

# %% [markdown]
# ## Importing libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15,4)

import numpy as np
import pandas as pd
import plotly
import plotly.graph_objs as go

import tensorflow as tf
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.metrics import mean_squared_error, mean_absolute_error
from plotly.offline import init_notebook_mode, iplot

# %% [markdown]
# ## Reading data

# %%
X_train = pd.read_csv('X_train_complete.csv', index_col=['date'])
y_train = pd.read_csv('y_train_complete.csv', index_col=['date'])

X_test = pd.read_csv('X_test.csv', index_col=['date'])
y_test = pd.read_csv('y_test.csv', index_col=['date'])

# %%
train_data = pd.concat([X_train, y_train], axis=1)
test_data = pd.concat([X_test, y_test], axis=1)

# %%
full_data = pd.concat([train_data, test_data], axis=0)

# %%
full_data
# Out:
#             maximum_atmospheric_pressure  minimum_atmospheric_pressure  \
# date
# 2017-01-01                    617.799658                    599.803362
# 2017-01-02                    620.147296                    599.795100
# 2017-01-03                    620.212662                    599.817608
# 2017-01-04                    616.165437                    599.787975
# 2017-01-05                    619.378317                    599.802992
# ...                                  ...                           ...
# 2017-11-25                    617.598033                    599.774778
# 2017-11-26                    618.306160                    599.760990
# 2017-11-27                    618.387980                    599.769210
# 2017-11-28                    615.830622                    599.787011
# 2017-11-29                    617.115633                    599.775633
#
#             precipitation  maximum_air_temperature  minimum_air_temperature  \
# date
# 2017-01-01       0.000000                30.318042                28.722792
# 2017-01-02       0.000000                29.630875                28.269417
# 2017-01-03       0.000000                29.409917                28.005583
# 2017-01-04       0.105833                29.755875                28.265958
# 2017-01-05       0.000000                28.977792                27.437292
# ...                   ...                      ...                      ...
# 2017-11-25       0.000000                26.162222                25.260667
# 2017-11-26       0.000000                25.160600                24.471200
# 2017-11-27       0.000000                26.168600                25.124500
# 2017-11-28       0.000000                26.670000                25.588444
# 2017-11-29       0.000000                27.488417                26.432167
#
#             maximum_relative_humidity  minimum_relative_humidity  \
# date
# 2017-01-01                  66.477167                  60.174625
# 2017-01-02                  67.488500                  61.223083
# 2017-01-03                  70.001792                  64.124500
# 2017-01-04                  69.879833                  63.227792
# 2017-01-05                  70.608750                  64.299542
# ...                               ...                        ...
# 2017-11-25                  77.043111                  72.860000
# 2017-11-26                  80.193500                  75.632100
# 2017-11-27                  79.476900                  73.358900
# 2017-11-28                  74.379444                  68.880667
# 2017-11-29                  72.656833                  67.606917
#
#             total_solar_radiation  maximum_temperature  minimum_temperature  \
# date
# 2017-01-01            2145.823333            21.408342            20.312011
# 2017-01-02            1951.849667            21.264383            20.061859
# 2017-01-03            2104.909208            21.635286            20.695279
# 2017-01-04            1963.737875            21.848865            20.813229
# 2017-01-05            2001.953125            21.344600            20.438310
# ...                           ...                  ...                  ...
# 2017-11-25            2500.997667            21.037083            20.542369
# 2017-11-26            2459.780530            20.800224            20.227300
# 2017-11-27            2507.158000            21.240160            20.642043
# 2017-11-28            2315.237867            20.622838            20.113804
# 2017-11-29            2247.963342            21.044991            20.470040
#
#             average_air_temperature  average_relative_humidity  wind_speed  \
# date
# 2017-01-01                29.543242                  63.174958    1.132543
# 2017-01-02                28.910676                  64.436735    1.087624
# 2017-01-03                28.650169                  67.002696    1.630787
# 2017-01-04                28.881102                  66.914866    1.921033
# 2017-01-05                28.167198                  67.434008    1.197141
# ...                             ...                        ...         ...
# 2017-11-25                25.666700                  75.260879    1.739529
# 2017-11-26                24.812676                  77.932516    1.118328
# 2017-11-27                25.678424                  76.354913    1.606195
# 2017-11-28                26.121304                  71.750116    1.845503
# 2017-11-29                26.989442                  70.110090    1.822953
#
#             total_solar_radiation.1  reference_evapotranspiration
# date
# 2017-01-01                 5.960620                      0.058537
# 2017-01-02                 5.421805                      0.048532
# 2017-01-03                 5.846970                      0.064639
# 2017-01-04                 5.454827                      0.072362
# 2017-01-05                 5.560981                      0.048342
# ...                             ...                           ...
# 2017-11-25                 6.947216                      0.035565
# 2017-11-26                 7.850408                      0.025799
# 2017-11-27                 7.510718                      0.034958
# 2017-11-28                 8.251289                      0.042553
# 2017-11-29                 7.229652                      0.049749
#
# [334 rows x 15 columns]

# %%
BATCH_SIZE = 32
N_INPUT = len(X_train)
N_FEATURES = len(X_train.columns)

# %%
trace0 = go.Scatter(
    x = train_data.index,
    y = train_data['reference_evapotranspiration'],
    name = 'Train'
)

trace1 = go.Scatter(
    x = test_data.index,
    y = test_data['reference_evapotranspiration'],
    name = 'Validation'
)

data = [trace0, trace1]

iplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="46544033-34fb-4cb8-bc7b-909718f5b8d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46544033-34fb-4cb8-bc7b-909718f5b8d5")) {                    Plotly.newPlot(                        "46544033-34fb-4cb8-bc7b-909718f5b8d5",                        [{"name":"Train","x":["2017-01-01","2017-01-02","2017-01-03","2017-01-04","2017-01-05","2017-01-06","2017-01-07","2017-01-08","2017-01-09","2017-01-10","2017-01-11","2017-01-12","2017-01-13","2017-01-14","2017-01-15","2017-01-16","2017-01-17","2017-01-18","2017-01-19","2017-01-20","2017-01-21","2017-01-22","2017-01-23","2017-01-24","2017-01-25","2017-01-26","2017-01-27","2017-01-28","2017-01-29","2017-01-30","2017-01-31","2017-02-01","2017-02-02","2017-02-03","2017-02-04","2017-02-05","2017-02-06","2017-02-07","2017-02-08","2017-02-09","2017-02-10","2017-02-11","2017-02-12","2017-02-13","2017-02-14","2017-02-15","2017-02-16","2017-02-17","2017-02-18","2017-02-19","2017-02-20","2017-02-21","2017-02-22","2017-02-23","2017-02-24","2017-02-25","2017-02-26","2017-02-27","2017-02-28","2017-03-01","2017-03-02","2017-03-03","2017-03-04","2017-03-05","2017-03-06","2017-03-07","2017-03-08","2017-03-09","2017-03-10","2017-03-11","2017-03-12","2017-03-13","2017-03-14","2017-03-15","2017-03-16","2017-03-17","2017-03-18","2017-03-19","2017-03-20","2017-03-21","2017-03-22","2017-03-23","2017-03-24","2017-03-25","2017-03-26","2017-03-27","2017-03-28","2017-03-29","2017-03-30","2017-03-31","2017-04-01","2017-04-02","2017-04-03","2017-04-04","2017-04-05","2017-04-06","2017-04-07","2017-04-08","2017-04-09","2017-04-10","2017-04-11","2017-04-12","2017-04-13","2017-04-14","2017-04-15","2017-04-16","2017-04-17","2017-04-18","2017-04-19","2017-04-20","2017-04-21","2017-04-22","2017-04-23","2017-04-24","2017-04-25","2017-04-26","2017-04-27","2017-04-28","2017-04-29","2017-04-30","2017-05-01","2017-05-02","2017-05-03","2017-05-04","2017-05-05","2017-05-06","2017-05-07","2017-05-08","2017-05-09","2017-05-10","2017-05-11","2017-05-12","2017-05-13","2017-05-14","2017-05-15","2017-05-16","2017-05-17","2017-05-18","2017-05-19","2017-05-20","2017-05-21","2017-05-22","2017-05-23","2017-05-24","2017-05-25","2017-05-26","2017-05-27","2017-05-28","2017-05-29","2017-05-30","2017-05-31","2017-06-01","2017-06-02","2017-06-03","2017-06-04","2017-06-05","2017-06-06","2017-06-07","2017-06-08","2017-06-09","2017-06-10","2017-06-11","2017-06-12","2017-06-13","2017-06-14","2017-06-15","2017-06-16","2017-06-17","2017-06-18","2017-06-19","2017-06-20","2017-06-21","2017-06-22","2017-06-23","2017-06-24","2017-06-25","2017-06-26","2017-06-27","2017-06-28","2017-06-29","2017-06-30","2017-07-01","2017-07-02","2017-07-03","2017-07-04","2017-07-05","2017-07-06","2017-07-07","2017-07-08","2017-07-09","2017-07-10","2017-07-11","2017-07-12","2017-07-13","2017-07-14","2017-07-15","2017-07-16","2017-07-17","2017-07-18","2017-07-19","2017-07-20","2017-07-21","2017-07-22","2017-07-23","2017-07-24","2017-07-25","2017-07-26","2017-07-27","2017-07-28","2017-07-29","2017-07-30","2017-07-31","2017-08-01","2017-08-02","2017-08-03","2017-08-04","2017-08-05","2017-08-06","2017-08-07","2017-08-08","2017-08-09","2017-08-10","2017-08-11","2017-08-12","2017-08-13","2017-08-14","2017-08-15","2017-08-16","2017-08-17","2017-08-18","2017-08-19","2017-08-20","2017-08-21","2017-08-22","2017-08-23","2017-08-24","2017-08-25","2017-08-26","2017-08-27","2017-08-28","2017-08-29","2017-08-30","2017-08-31","2017-09-01","2017-09-02","2017-09-03","2017-09-04","2017-09-05","2017-09-06","2017-09-07","2017-09-08","2017-09-09","2017-09-10","2017-09-11","2017-09-12","2017-09-13","2017-09-14","2017-09-15","2017-09-16","2017-09-17","2017-09-18","2017-09-19","2017-09-20","2017-09-21", ...

# %%
# MASE implemented courtesy of sktime - https://github.com/alan-turing-institute/sktime/blob/ee7a06843a44f4aaec7582d847e36073a9ab0566/sktime/performance_metrics/forecasting/_functions.py#L16
def mean_absolute_scaled_error(y_true, y_pred):
  """
  Implement MASE (assuming no seasonality of data).
  """
  mae = tf.reduce_mean(tf.abs(y_true - y_pred))

  # Find MAE of naive forecast (no seasonality)
  mae_naive_no_season = tf.reduce_mean(tf.abs(y_true[1:] - y_true[:-1])) # our seasonality is 1 day (hence the shifting of 1 day)

  return mae / mae_naive_no_season

# %%
def evaluate_preds(y_true, y_pred):
  # Make sure float32 (for metric calculations)
  y_true = tf.cast(y_true, dtype=tf.float32)
  y_pred = tf.cast(y_pred, dtype=tf.float32)

  # Calculate various metrics
  mae = tf.keras.metrics.mean_absolute_error(y_true, y_pred)
  mse = tf.keras.metrics.mean_squared_error(y_true, y_pred) # puts and emphasis on outliers (all errors get squared)
  rmse = tf.sqrt(mse)
  mape = tf.keras.metrics.mean_absolute_percentage_error(y_true, y_pred)
  mase = mean_absolute_scaled_error(y_true, y_pred)
  
  return {"mae": mae.numpy(),
          "mse": mse.numpy(),
          "rmse": rmse.numpy(),
          "mape": mape.numpy(),
          "mase": mase.numpy()}

# %%
HORIZON = 1
WINDOW_SIZE = 7

# %%
# Create function to label windowed data
def get_labelled_windows(x, horizon=1):
  """
  Creates labels for windowed dataset.

  E.g. if horizon=1 (default)
  Input: [1, 2, 3, 4, 5, 6] -> Output: ([1, 2, 3, 4, 5], [6])
  """
  return x[:, :-horizon], x[:, -horizon:]

# %%
# Test out the window labelling function
test_window, test_label = get_labelled_windows(tf.expand_dims(tf.range(8)+1, axis=0), horizon=HORIZON)
print(f"Window: {tf.squeeze(test_window).numpy()} -> Label: {tf.squeeze(test_label).numpy()}")
# Out:
# Window: [1 2 3 4 5 6 7] -> Label: 8

# %%
# Create function to view NumPy arrays as windows 
def make_windows(x, window_size=7, horizon=1):
  """
  Turns a 1D array into a 2D array of sequential windows of window_size.
  """
  # 1. Create a window of specific window_size (add the horizon on the end for later labelling)
  window_step = np.expand_dims(np.arange(window_size+horizon), axis=0)
  # print(f"Window step:\n {window_step}")

  # 2. Create a 2D array of multiple window steps (minus 1 to account for 0 indexing)
  window_indexes = window_step + np.expand_dims(np.arange(len(x)-(window_size+horizon-1)), axis=0).T # create 2D array of windows of size window_size
  # print(f"Window indexes:\n {window_indexes[:3], window_indexes[-3:], window_indexes.shape}")

  # 3. Index on the target array (time series) with 2D array of multiple window steps
  windowed_array = x[window_indexes]

  # 4. Get the labelled windows
  windows, labels = get_labelled_windows(windowed_array, horizon=horizon)

  return windows, labels

# %%
timesteps = full_data.index.to_numpy()
re = full_data["reference_evapotranspiration"].to_numpy()

# %%
full_windows, full_labels = make_windows(re, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (327, 327)

# %%
# View the first 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i]} -> Label: {full_labels[i]}")
# Out:
# Window: [0.05853737 0.04853203 0.06463882 0.0723622  0.04834153 0.0520071
#  0.04217207] -> Label: [0.05636294]
# Window: [0.04853203 0.06463882 0.0723622  0.04834153 0.0520071  0.04217207
#  0.05636294] -> Label: [0.04979837]
# Window: [0.06463882 0.0723622  0.04834153 0.0520071  0.04217207 0.05636294
#  0.04979837] -> Label: [0.04917493]

# %%
# Make the train/test splits
def make_train_test_splits(windows, labels, test_split=0.2):
  """
  Splits matching pairs of windows and labels into train and test splits.
  """
  split_size = int(len(windows) * (1-test_split)) # this will default to 80% train/20% test
  train_windows = windows[:split_size]
  train_labels = labels[:split_size]
  test_windows = windows[split_size:]
  test_labels = labels[split_size:]
  return train_windows, test_windows, train_labels, test_labels

# %%
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(full_windows, full_labels)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (261, 66, 261, 66)

# %%
import os

# Create a function to implement a ModelCheckpoint callback with a specific filename 
def create_model_checkpoint(model_name, save_path="model_experiments"):
  return tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(save_path, model_name), # create filepath to save model
                                            verbose=0, # only output a limited amount of text
                                            save_best_only=True) # save only the best model to file

# %%
train_windows.shape, train_labels.shape
# Out:
# ((261, 7), (261, 1))

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', mode = 'min',
                                                  verbose = 1, patience = 20)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                                                 patience=5, min_lr=0.00001)

# %%
from tensorflow.keras.layers import Dense, LSTM, Dropout, Bidirectional, Conv1D
import tensorflow as tf
from tensorflow.keras import layers

# %%
# %%time

# Create model
model = tf.keras.Sequential([
  # Create Lambda layer to reshape inputs, without this layer, the model will error
  layers.Lambda(lambda x: tf.expand_dims(x, axis=1)), # resize the inputs to adjust for window size / Conv1D 3D input requirements
  layers.Conv1D(filters=64, kernel_size=5, padding="causal", activation="relu"),
  layers.Dense(HORIZON)
], name="model_conv1D")

rmse = tf.keras.metrics.RootMeanSquaredError()

# Compile model
model.compile(loss="mean_squared_error",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=[rmse,'mae'])

history_1 = model.fit(train_windows,
            train_labels,
            epochs=100,
            verbose=1,
            batch_size=128,
            validation_data=(test_windows, test_labels),
            callbacks=[create_model_checkpoint(model_name=model.name)])
# Out:
# Epoch 1/100
# 1/3 [=========>....................] - ETA: 1s - loss: 0.0019 - root_mean_squared_error: 0.0433 - mae: 0.0388INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 439ms/step - loss: 0.0016 - root_mean_squared_error: 0.0401 - mae: 0.0354 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0553 - val_mae: 0.0535
# Epoch 2/100
# 1/3 [=========>....................] - ETA: 0s - loss: 7.6929e-04 - root_mean_squared_error: 0.0277 - mae: 0.0222INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 348ms/step - loss: 6.2377e-04 - root_mean_squared_error: 0.0250 - mae: 0.0196 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0364 - val_mae: 0.0342
# Epoch 3/100
# 1/3 [=========>....................] - ETA: 0s - loss: 2.8430e-04 - root_mean_squared_error: 0.0169 - mae: 0.0137INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 359ms/step - loss: 2.7012e-04 - root_mean_squared_error: 0.0164 - mae: 0.0135 - val_loss: 5.6635e-04 - val_root_mean_squared_error: 0.0238 - val_mae: 0.0218
# Epoch 4/100
# 1/3 [=========>....................] - ETA: 0s - loss: 3.0629e-04 - root_mean_squared_error: 0.0175 - mae: 0.0149INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 364ms/step - loss: 2.8138e-04 - root_mean_squared_error: 0.0168 - mae: 0.0140 - val_loss: 3.7687e-04 - val_root_mean_squared_error: 0.0194 - val_mae: 0.0174
# Epoch 5/100
# 1/3 [=========>....................] - ETA: 0s - loss: 3.6055e-04 - root_mean_squared_error: 0.0190 - mae: 0.0161INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 373ms/step - loss: 3.0947e-04 - root_mean_squared_error: 0.0176 - mae: 0.0147 - val_loss: 3.7537e-04 - val_root_mean_squared_error: 0.0194 - val_mae: 0.0174
# Epoch 6/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.7110e-04 - root_mean_squared_error: 0.0165 - mae: 0.0137 - val_loss: 4.9706e-04 - val_root_mean_squared_error: 0.0223 - val_mae: 0.0203
# Epoch 7/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.1824e-04 - root_mean_squared_error: 0.0148 - mae: 0.0121 - val_loss: 6.4359e-04 - val_root_mean_squared_error: 0.0254 - val_mae: 0.0233
# Epoch 8/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.0142e-04 - root_mean_squared_error: 0.0142 - mae: 0.0114 - val_loss: 7.3800e-04 - val_root_mean_squared_error: 0.0272 - val_mae: 0.0251
# Epoch 9/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.0363e-04 - root_mean_squared_error: 0.0143 - mae: 0.0114 - val_loss: 7.5911e-04 - val_root_mean_squared_error: 0.0276 - val_mae: 0.0255
# Epoch 10/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.0301e-04 - root_mean_squared_error: 0.0142 - mae: 0.0113 - val_loss: 6.8546e-04 - val_root_mean_squared_error: 0.0262 - val_mae: 0.0242
# Epoch 11/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1.9263e-04 - root_mean_squared_error: 0.0139 - mae: 0.0110 - val_loss: 5.4754e-04 - val_root_mean_squared_error: 0.0234 - val_mae: 0.0214
# Epoch 12/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.8364e-04 - root_mean_squared_error: 0.0136 - mae: 0.0108 - val_loss: 4.5254e-04 - val_root_mean_squared_error: 0.0213 - val_mae: 0.0193
# Epoch 13/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.8257e-04 - root_mean_squared_error: 0.0135 - mae: 0.0108 - val_loss: 4.0998e-04 - val_root_mean_squared_error: 0.0202 - val_mae: 0.0183
# Epoch 14/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.7976e-04 - root_mean_squared_error: 0.0134 - mae: 0.0107 - val_loss: 4.0414e-04 - val_root_mean_squared_error: 0.0201 - val_mae: 0.0181
# Epoch 15/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.7373e-04 - root_mean_squared_error: 0.0132 - mae: 0.0105 - val_loss: 4.1534e-04 - val_root_mean_squared_error: 0.0204 - val_mae: 0.0184
# Epoch 16/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.6802e-04 - root_mean_squared_error: 0.0130 - mae: 0.0103 - val_loss: 4.3198e-04 - val_root_mean_squared_error: 0.0208 - val_mae: 0.0188
# Epoch 17/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.6343e-04 - root_mean_squared_error: 0.0128 - mae: 0.0101 - val_loss: 4.6556e-04 - val_root_mean_squared_error: 0.0216 - val_mae: 0.0196
# Epoch 18/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.6350e-04 - root_mean_squared_error: 0.0128 - mae: 0.0100 - val_loss: 4.4733e-04 - val_root_mean_squared_error: 0.0212 - val_mae: 0.0192
# Epoch 19/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.6511e-04 - root_mean_squared_error: 0.0128 - mae: 0.0103INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 387ms/step - loss: 1.5776e-04 - root_mean_squared_error: 0.0126 - mae: 0.0099 - val_loss: 3.4781e-04 - val_root_mean_squared_error: 0.0186 - val_mae: 0.0166
# Epoch 20/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.6119e-04 - root_mean_squared_error: 0.0127 - mae: 0.0103INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 614ms/step - loss: 1.5612e-04 - root_mean_squared_error: 0.0125 - mae: 0.0099 - val_loss: 2.8229e-04 - val_root_mean_squared_error: 0.0168 - val_mae: 0.0146
# Epoch 21/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.4296e-04 - root_mean_squared_error: 0.0120 - mae: 0.0095INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 383ms/step - loss: 1.6054e-04 - root_mean_squared_error: 0.0127 - mae: 0.0100 - val_loss: 2.5235e-04 - val_root_mean_squared_error: 0.0159 - val_mae: 0.0137
# Epoch 22/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.6136e-04 - root_mean_squared_error: 0.0127 - mae: 0.0100 - val_loss: 2.5624e-04 - val_root_mean_squared_error: 0.0160 - val_mae: 0.0138
# Epoch 23/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.5409e-04 - root_mean_squared_error: 0.0124 - mae: 0.0098 - val_loss: 2.9854e-04 - val_root_mean_squared_error: 0.0173 - val_mae: 0.0152
# Epoch 24/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.4470e-04 - root_mean_squared_error: 0.0120 - mae: 0.0094 - val_loss: 3.5960e-04 - val_root_mean_squared_error: 0.0190 - val_mae: 0.0169
# Epoch 25/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.4812e-04 - root_mean_squared_error: 0.0122 - mae: 0.0096 - val_loss: 4.0900e-04 - val_root_mean_squared_error: 0.0202 - val_mae: 0.0182
# Epoch 26/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.5307e-04 - root_mean_squared_error: 0.0124 - mae: 0.0097 - val_loss: 3.5331e-04 - val_root_mean_squared_error: 0.0188 - val_mae: 0.0167
# Epoch 27/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.7086e-04 - root_mean_squared_error: 0.0131 - mae: 0.0099INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 380ms/step - loss: 1.4250e-04 - root_mean_squared_error: 0.0119 - mae: 0.0093 - val_loss: 2.4458e-04 - val_root_mean_squared_error: 0.0156 - val_mae: 0.0134
# Epoch 28/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.1123e-04 - root_mean_squared_error: 0.0105 - mae: 0.0083INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 394ms/step - loss: 1.4007e-04 - root_mean_squared_error: 0.0118 - mae: 0.0092 - val_loss: 1.7708e-04 - val_root_mean_squared_error: 0.0133 - val_mae: 0.0109
# Epoch 29/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.3355e-04 - root_mean_squared_error: 0.0116 - mae: 0.0091INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 369ms/step - loss: 1.5696e-04 - root_mean_squared_error: 0.0125 - mae: 0.0097 - val_loss: 1.6015e-04 - val_root_mean_squared_error: 0.0127 - val_mae: 0.0100
# Epoch 30/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.6537e-04 - root_mean_squared_error: 0.0129 - mae: 0.0101 - val_loss: 1.7148e-04 - val_root_mean_squared_error: 0.0131 - val_mae: 0.0106
# Epoch 31/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.4543e-04 - root_mean_squared_error: 0.0121 - mae: 0.0093 - val_loss: 2.2925e-04 - val_root_mean_squared_error: 0.0151 - val_mae: 0.0129
# Epoch 32/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3297e-04 - root_mean_squared_error: 0.0115 - mae: 0.0090 - val_loss: 3.0017e-04 - val_root_mean_squared_error: 0.0173 - val_mae: 0.0152
# Epoch 33/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.4096e-04 - root_mean_squared_error: 0.0119 - mae: 0.0093 - val_loss: 3.2847e-04 - val_root_mean_squared_error: 0.0181 - val_mae: 0.0160
# Epoch 34/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.4646e-04 - root_mean_squared_error: 0.0121 - mae: 0.0095 - val_loss: 2.9354e-04 - val_root_mean_squared_error: 0.0171 - val_mae: 0.0150
# Epoch 35/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.3784e-04 - root_mean_squared_error: 0.0117 - mae: 0.0091 - val_loss: 2.2756e-04 - val_root_mean_squared_error: 0.0151 - val_mae: 0.0129
# Epoch 36/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2854e-04 - root_mean_squared_error: 0.0113 - mae: 0.0088 - val_loss: 2.0605e-04 - val_root_mean_squared_error: 0.0144 - val_mae: 0.0121
# Epoch 37/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2818e-04 - root_mean_squared_error: 0.0113 - mae: 0.0088 - val_loss: 2.1165e-04 - val_root_mean_squared_error: 0.0145 - val_mae: 0.0123
# Epoch 38/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2711e-04 - root_mean_squared_error: 0.0113 - mae: 0.0087 - val_loss: 2.2675e-04 - val_root_mean_squared_error: 0.0151 - val_mae: 0.0128
# Epoch 39/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2802e-04 - root_mean_squared_error: 0.0113 - mae: 0.0088 - val_loss: 2.3712e-04 - val_root_mean_squared_error: 0.0154 - val_mae: 0.0132
# Epoch 40/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2857e-04 - root_mean_squared_error: 0.0113 - mae: 0.0088 - val_loss: 2.2670e-04 - val_root_mean_squared_error: 0.0151 - val_mae: 0.0128
# Epoch 41/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2713e-04 - root_mean_squared_error: 0.0113 - mae: 0.0087 - val_loss: 1.9928e-04 - val_root_mean_squared_error: 0.0141 - val_mae: 0.0119
# Epoch 42/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2470e-04 - root_mean_squared_error: 0.0112 - mae: 0.0086 - val_loss: 1.7170e-04 - val_root_mean_squared_error: 0.0131 - val_mae: 0.0107
# Epoch 43/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2753e-04 - root_mean_squared_error: 0.0113 - mae: 0.0087 - val_loss: 1.6650e-04 - val_root_mean_squared_error: 0.0129 - val_mae: 0.0104
# Epoch 44/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1.2818e-04 - root_mean_squared_error: 0.0113 - mae: 0.0087 - val_loss: 1.6670e-04 - val_root_mean_squared_error: 0.0129 - val_mae: 0.0104
# Epoch 45/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.2640e-04 - root_mean_squared_error: 0.0112 - mae: 0.0086 - val_loss: 1.7761e-04 - val_root_mean_squared_error: 0.0133 - val_mae: 0.0110
# Epoch 46/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1.2305e-04 - root_mean_squared_error: 0.0111 - mae: 0.0085 - val_loss: 2.0293e-04 - val_root_mean_squared_error: 0.0142 - val_mae: 0.0120
# Epoch 47/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2416e-04 - root_mean_squared_error: 0.0111 - mae: 0.0086 - val_loss: 2.2465e-04 - val_root_mean_squared_error: 0.0150 - val_mae: 0.0128
# Epoch 48/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2800e-04 - root_mean_squared_error: 0.0113 - mae: 0.0088 - val_loss: 2.2715e-04 - val_root_mean_squared_error: 0.0151 - val_mae: 0.0129
# Epoch 49/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2771e-04 - root_mean_squared_error: 0.0113 - mae: 0.0088 - val_loss: 2.0145e-04 - val_root_mean_squared_error: 0.0142 - val_mae: 0.0120
# Epoch 50/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.2202e-04 - root_mean_squared_error: 0.0110 - mae: 0.0085 - val_loss: 1.7246e-04 - val_root_mean_squared_error: 0.0131 - val_mae: 0.0107
# Epoch 51/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2119e-04 - root_mean_squared_error: 0.0110 - mae: 0.0084 - val_loss: 1.6281e-04 - val_root_mean_squared_error: 0.0128 - val_mae: 0.0103
# Epoch 52/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0094e-04 - root_mean_squared_error: 0.0100 - mae: 0.0079INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 373ms/step - loss: 1.2208e-04 - root_mean_squared_error: 0.0110 - mae: 0.0085 - val_loss: 1.5999e-04 - val_root_mean_squared_error: 0.0126 - val_mae: 0.0102
# Epoch 53/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2279e-04 - root_mean_squared_error: 0.0111 - mae: 0.0085 - val_loss: 1.6125e-04 - val_root_mean_squared_error: 0.0127 - val_mae: 0.0102
# Epoch 54/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2125e-04 - root_mean_squared_error: 0.0110 - mae: 0.0084 - val_loss: 1.6676e-04 - val_root_mean_squared_error: 0.0129 - val_mae: 0.0105
# Epoch 55/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.3250e-04 - root_mean_squared_error: 0.0115 - mae: 0.0085INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 356ms/step - loss: 1.2040e-04 - root_mean_squared_error: 0.0110 - mae: 0.0084 - val_loss: 1.5833e-04 - val_root_mean_squared_error: 0.0126 - val_mae: 0.0101
# Epoch 56/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.2794e-04 - root_mean_squared_error: 0.0113 - mae: 0.0090INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 357ms/step - loss: 1.2130e-04 - root_mean_squared_error: 0.0110 - mae: 0.0084 - val_loss: 1.5571e-04 - val_root_mean_squared_error: 0.0125 - val_mae: 0.0099
# Epoch 57/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.1283e-04 - root_mean_squared_error: 0.0106 - mae: 0.0083INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 374ms/step - loss: 1.2148e-04 - root_mean_squared_error: 0.0110 - mae: 0.0084 - val_loss: 1.5554e-04 - val_root_mean_squared_error: 0.0125 - val_mae: 0.0099
# Epoch 58/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.2071e-04 - root_mean_squared_error: 0.0110 - mae: 0.0084 - val_loss: 1.6097e-04 - val_root_mean_squared_error: 0.0127 - val_mae: 0.0102
# Epoch 59/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1891e-04 - root_mean_squared_error: 0.0109 - mae: 0.0083 - val_loss: 1.6473e-04 - val_root_mean_squared_error: 0.0128 - val_mae: 0.0104
# Epoch 60/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1801e-04 - root_mean_squared_error: 0.0109 - mae: 0.0083 - val_loss: 1.6960e-04 - val_root_mean_squared_error: 0.0130 - val_mae: 0.0106
# Epoch 61/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1760e-04 - root_mean_squared_error: 0.0108 - mae: 0.0083 - val_loss: 1.7337e-04 - val_root_mean_squared_error: 0.0132 - val_mae: 0.0108
# Epoch 62/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1730e-04 - root_mean_squared_error: 0.0108 - mae: 0.0083 - val_loss: 1.7659e-04 - val_root_mean_squared_error: 0.0133 - val_mae: 0.0110
# Epoch 63/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1799e-04 - root_mean_squared_error: 0.0109 - mae: 0.0083 - val_loss: 1.7191e-04 - val_root_mean_squared_error: 0.0131 - val_mae: 0.0108
# Epoch 64/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.1098e-04 - root_mean_squared_error: 0.0105 - mae: 0.0078INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 387ms/step - loss: 1.1680e-04 - root_mean_squared_error: 0.0108 - mae: 0.0083 - val_loss: 1.5424e-04 - val_root_mean_squared_error: 0.0124 - val_mae: 0.0099
# Epoch 65/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.1958e-04 - root_mean_squared_error: 0.0109 - mae: 0.0088INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 369ms/step - loss: 1.1763e-04 - root_mean_squared_error: 0.0108 - mae: 0.0083 - val_loss: 1.4877e-04 - val_root_mean_squared_error: 0.0122 - val_mae: 0.0096
# Epoch 66/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1875e-04 - root_mean_squared_error: 0.0109 - mae: 0.0083 - val_loss: 1.5078e-04 - val_root_mean_squared_error: 0.0123 - val_mae: 0.0097
# Epoch 67/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1721e-04 - root_mean_squared_error: 0.0108 - mae: 0.0083 - val_loss: 1.5723e-04 - val_root_mean_squared_error: 0.0125 - val_mae: 0.0101
# Epoch 68/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.1660e-04 - root_mean_squared_error: 0.0108 - mae: 0.0082 - val_loss: 1.5919e-04 - val_root_mean_squared_error: 0.0126 - val_mae: 0.0102
# Epoch 69/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1551e-04 - root_mean_squared_error: 0.0107 - mae: 0.0082 - val_loss: 1.8760e-04 - val_root_mean_squared_error: 0.0137 - val_mae: 0.0114
# Epoch 70/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2014e-04 - root_mean_squared_error: 0.0110 - mae: 0.0085 - val_loss: 2.0717e-04 - val_root_mean_squared_error: 0.0144 - val_mae: 0.0122
# Epoch 71/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2307e-04 - root_mean_squared_error: 0.0111 - mae: 0.0087 - val_loss: 1.8817e-04 - val_root_mean_squared_error: 0.0137 - val_mae: 0.0115
# Epoch 72/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1721e-04 - root_mean_squared_error: 0.0108 - mae: 0.0083 - val_loss: 1.6261e-04 - val_root_mean_squared_error: 0.0128 - val_mae: 0.0104
# Epoch 73/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1401e-04 - root_mean_squared_error: 0.0107 - mae: 0.0082 - val_loss: 1.5030e-04 - val_root_mean_squared_error: 0.0123 - val_mae: 0.0097
# Epoch 74/100
# 1/3 [=========>....................] - ETA: 0s - loss: 9.7861e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 368ms/step - loss: 1.1420e-04 - root_mean_squared_error: 0.0107 - mae: 0.0081 - val_loss: 1.4298e-04 - val_root_mean_squared_error: 0.0120 - val_mae: 0.0093
# Epoch 75/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1634e-04 - root_mean_squared_error: 0.0108 - mae: 0.0082 - val_loss: 1.4317e-04 - val_root_mean_squared_error: 0.0120 - val_mae: 0.0093
# Epoch 76/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1465e-04 - root_mean_squared_error: 0.0107 - mae: 0.0082 - val_loss: 1.5212e-04 - val_root_mean_squared_error: 0.0123 - val_mae: 0.0099
# Epoch 77/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1281e-04 - root_mean_squared_error: 0.0106 - mae: 0.0081 - val_loss: 1.5471e-04 - val_root_mean_squared_error: 0.0124 - val_mae: 0.0100
# Epoch 78/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1256e-04 - root_mean_squared_error: 0.0106 - mae: 0.0081 - val_loss: 1.4869e-04 - val_root_mean_squared_error: 0.0122 - val_mae: 0.0097
# Epoch 79/100
# 3/3 [==============================] - 0s 28ms/step - loss: 1.1247e-04 - root_mean_squared_error: 0.0106 - mae: 0.0081 - val_loss: 1.4381e-04 - val_root_mean_squared_error: 0.0120 - val_mae: 0.0094
# Epoch 80/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0624e-04 - root_mean_squared_error: 0.0103 - mae: 0.0081INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 361ms/step - loss: 1.1363e-04 - root_mean_squared_error: 0.0107 - mae: 0.0081 - val_loss: 1.3847e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0090
# Epoch 81/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1523e-04 - root_mean_squared_error: 0.0107 - mae: 0.0082 - val_loss: 1.4403e-04 - val_root_mean_squared_error: 0.0120 - val_mae: 0.0094
# Epoch 82/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1220e-04 - root_mean_squared_error: 0.0106 - mae: 0.0081 - val_loss: 1.7690e-04 - val_root_mean_squared_error: 0.0133 - val_mae: 0.0110
# Epoch 83/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1969e-04 - root_mean_squared_error: 0.0109 - mae: 0.0086 - val_loss: 2.2482e-04 - val_root_mean_squared_error: 0.0150 - val_mae: 0.0129
# Epoch 84/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.3506e-04 - root_mean_squared_error: 0.0116 - mae: 0.0092 - val_loss: 1.9677e-04 - val_root_mean_squared_error: 0.0140 - val_mae: 0.0118
# Epoch 85/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.3168e-04 - root_mean_squared_error: 0.0115 - mae: 0.0090INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 375ms/step - loss: 1.1769e-04 - root_mean_squared_error: 0.0108 - mae: 0.0084 - val_loss: 1.3794e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0091
# Epoch 86/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0630e-04 - root_mean_squared_error: 0.0103 - mae: 0.0079INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 355ms/step - loss: 1.1835e-04 - root_mean_squared_error: 0.0109 - mae: 0.0083 - val_loss: 1.3709e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0088
# Epoch 87/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2727e-04 - root_mean_squared_error: 0.0113 - mae: 0.0086 - val_loss: 1.4427e-04 - val_root_mean_squared_error: 0.0120 - val_mae: 0.0095
# Epoch 88/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1076e-04 - root_mean_squared_error: 0.0105 - mae: 0.0081 - val_loss: 2.0516e-04 - val_root_mean_squared_error: 0.0143 - val_mae: 0.0122
# Epoch 89/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2490e-04 - root_mean_squared_error: 0.0112 - mae: 0.0088 - val_loss: 1.9262e-04 - val_root_mean_squared_error: 0.0139 - val_mae: 0.0117
# Epoch 90/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1545e-04 - root_mean_squared_error: 0.0107 - mae: 0.0083 - val_loss: 1.4271e-04 - val_root_mean_squared_error: 0.0119 - val_mae: 0.0094
# Epoch 91/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.2420e-04 - root_mean_squared_error: 0.0111 - mae: 0.0083INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 646ms/step - loss: 1.1035e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.3440e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0087
# Epoch 92/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.3194e-04 - root_mean_squared_error: 0.0115 - mae: 0.0091INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 366ms/step - loss: 1.2673e-04 - root_mean_squared_error: 0.0113 - mae: 0.0086 - val_loss: 1.3353e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0087
# Epoch 93/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.1804e-04 - root_mean_squared_error: 0.0109 - mae: 0.0083 - val_loss: 1.4494e-04 - val_root_mean_squared_error: 0.0120 - val_mae: 0.0095
# Epoch 94/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1046e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.7321e-04 - val_root_mean_squared_error: 0.0132 - val_mae: 0.0109
# Epoch 95/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1395e-04 - root_mean_squared_error: 0.0107 - mae: 0.0083 - val_loss: 1.5953e-04 - val_root_mean_squared_error: 0.0126 - val_mae: 0.0102
# Epoch 96/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0938e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.3490e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0089
# Epoch 97/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1539e-04 - root_mean_squared_error: 0.0107 - mae: 0.0082 - val_loss: 1.3601e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0088
# Epoch 98/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0343e-04 - root_mean_squared_error: 0.0102 - mae: 0.0081INFO:tensorflow:Assets written to: model_experiments/model_conv1D/assets
# 3/3 [==============================] - 1s 373ms/step - loss: 1.2451e-04 - root_mean_squared_error: 0.0112 - mae: 0.0086 - val_loss: 1.3296e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0087
# Epoch 99/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1443e-04 - root_mean_squared_error: 0.0107 - mae: 0.0082 - val_loss: 1.4738e-04 - val_root_mean_squared_error: 0.0121 - val_mae: 0.0097
# Epoch 100/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0877e-04 - root_mean_squared_error: 0.0104 - mae: 0.0080 - val_loss: 1.6141e-04 - val_root_mean_squared_error: 0.0127 - val_mae: 0.0103
# CPU times: user 22.9 s, sys: 607 ms, total: 23.5 s
# Wall time: 23.6 s

# %%
model.summary()
# Out:
# Model: "model_conv1D"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda_7 (Lambda)           (None, 1, 7)              0
#
#  conv1d_14 (Conv1D)          (None, 1, 64)             2304
#
#  dense_16 (Dense)            (None, 1, 1)              65
#
# =================================================================
# Total params: 2,369
# Trainable params: 2,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.figure(figsize=(10,6))
plt.plot(history_1.history['loss'])
plt.plot(history_1.history['val_loss'])
plt.title('CNN model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(history_1.history['mae'])
plt.plot(history_1.history['val_mae'])
plt.title('CNN model')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(history_1.history['root_mean_squared_error'])
plt.plot(history_1.history['val_root_mean_squared_error'])
plt.title('CNN model')
plt.ylabel('rmse')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
model.evaluate(test_windows, test_labels)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6141e-04 - root_mean_squared_error: 0.0127 - mae: 0.0103
# [0.00016141239029821008, 0.012704817578196526, 0.010324354283511639]

# %%
model = tf.keras.models.load_model("model_experiments/model_conv1D")
model.evaluate(test_windows, test_labels)
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3296e-04 - root_mean_squared_error: 0.0115 - mae: 0.0087
# [0.00013296424003783613, 0.011531012132763863, 0.008690427988767624]

# %%
def make_preds(model, input_data):
  """
  Uses model to make predictions on input_data.

  Parameters
  ----------
  model: trained model 
  input_data: windowed input data (same kind of data model was trained on)

  Returns model predictions on input_data.
  """
  forecast = model.predict(input_data)
  return tf.squeeze(forecast) # return 1D array of predictions

# %%
# Make predictions using model_dnn on the test dataset and view the results
model_preds = make_preds(model, test_windows)
len(model_preds), model_preds[:10]
# Out:
# (66, <tf.Tensor: shape=(10,), dtype=float32, numpy=
#  array([0.04908531, 0.05142915, 0.05771179, 0.05900952, 0.0627019 ,
#         0.06583834, 0.06407106, 0.06565234, 0.06960471, 0.06487384],
#        dtype=float32)>)

# %%
# Evaluate preds
model_results = evaluate_preds(y_true=tf.squeeze(test_labels), # reduce to right shape
                                 y_pred=model_preds)
model_results
# Out:
# {'mae': 0.008690428,
#  'mape': 15.141067,
#  'mase': 0.9583155,
#  'mse': 0.00013296425,
#  'rmse': 0.011531013}

# %%
plt.figure(figsize=(12,5))  
plt.plot(tf.squeeze(test_labels), color='blue', label='ET0 true')  
plt.plot(model_preds, color='red', label='ET0 predicted')  
plt.title('ET0 Forecasting')  
plt.xlabel('Date')  
plt.ylabel('ET0')  
plt.legend()
#plt.savefig("eto.png")
plt.show()

# %% [markdown]
# # Saving cnn model and applying transfer learning

# %%
model.save('cnn_model.h5')

# %%
loaded_model=tf.keras.models.load_model('cnn_model.h5')

# %%
loaded_model.layers
# Out:
# [<keras.layers.core.lambda_layer.Lambda at 0x7fc5cf7aa650>,
#  <keras.layers.convolutional.Conv1D at 0x7fc5d19e63d0>,
#  <keras.layers.core.dense.Dense at 0x7fc5d24576d0>]

# %%
model1=Sequential()
for layer in loaded_model.layers[:-1]:
 model1.add(layer)
 
# Freeze all the layers of base model
for layer in loaded_model.layers:
 layer.trainable=False
 
# adding new layers

model1.add(Conv1D(filters=64, kernel_size=5, padding="causal", activation="relu"))

#model1.add(Dropout(0.2))
model1.add(Dense(1))

# %%
model1.build(input_shape=(1,WINDOW_SIZE))

# %%
model1.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda_7 (Lambda)           multiple                  0
#
#  conv1d_14 (Conv1D)          multiple                  2304
#
#  conv1d_15 (Conv1D)          (1, 1, 64)                20544
#
#  dense_17 (Dense)            (1, 1, 1)                 65
#
# =================================================================
# Total params: 22,913
# Trainable params: 20,609
# Non-trainable params: 2,304
# _________________________________________________________________

# %%
rmse = tf.keras.metrics.RootMeanSquaredError()

# Compile model
model1.compile(loss="mean_squared_error",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=[rmse,'mae'])

# %%
# %%time
history_2 = model1.fit(x=train_windows, # train windows of 7 timesteps of Bitcoin prices
              y=train_labels, # horizon value of 1 (using the previous 7 timesteps to predict next day)
              epochs=100,
              verbose=1,
              batch_size=128,
              validation_data=(test_windows, test_labels),
              callbacks=[create_model_checkpoint(model_name='loaded_model')])
# Out:
# Epoch 1/100
# 1/3 [=========>....................] - ETA: 2s - loss: 0.0014 - root_mean_squared_error: 0.0371 - mae: 0.0329INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 3s 863ms/step - loss: 0.0012 - root_mean_squared_error: 0.0339 - mae: 0.0294 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0427 - val_mae: 0.0407
# Epoch 2/100
# 1/3 [=========>....................] - ETA: 0s - loss: 4.2730e-04 - root_mean_squared_error: 0.0207 - mae: 0.0161INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 2s 792ms/step - loss: 3.4539e-04 - root_mean_squared_error: 0.0186 - mae: 0.0147 - val_loss: 6.1846e-04 - val_root_mean_squared_error: 0.0249 - val_mae: 0.0228
# Epoch 3/100
# 1/3 [=========>....................] - ETA: 0s - loss: 2.2470e-04 - root_mean_squared_error: 0.0150 - mae: 0.0124INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 732ms/step - loss: 2.4677e-04 - root_mean_squared_error: 0.0157 - mae: 0.0130 - val_loss: 3.4104e-04 - val_root_mean_squared_error: 0.0185 - val_mae: 0.0164
# Epoch 4/100
# 3/3 [==============================] - 0s 16ms/step - loss: 2.9932e-04 - root_mean_squared_error: 0.0173 - mae: 0.0145 - val_loss: 3.7031e-04 - val_root_mean_squared_error: 0.0192 - val_mae: 0.0172
# Epoch 5/100
# 3/3 [==============================] - 0s 18ms/step - loss: 2.6304e-04 - root_mean_squared_error: 0.0162 - mae: 0.0134 - val_loss: 5.0144e-04 - val_root_mean_squared_error: 0.0224 - val_mae: 0.0204
# Epoch 6/100
# 3/3 [==============================] - 0s 17ms/step - loss: 2.1018e-04 - root_mean_squared_error: 0.0145 - mae: 0.0118 - val_loss: 6.7672e-04 - val_root_mean_squared_error: 0.0260 - val_mae: 0.0240
# Epoch 7/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.9676e-04 - root_mean_squared_error: 0.0140 - mae: 0.0113 - val_loss: 7.7607e-04 - val_root_mean_squared_error: 0.0279 - val_mae: 0.0258
# Epoch 8/100
# 3/3 [==============================] - 0s 15ms/step - loss: 2.0091e-04 - root_mean_squared_error: 0.0142 - mae: 0.0113 - val_loss: 7.3808e-04 - val_root_mean_squared_error: 0.0272 - val_mae: 0.0251
# Epoch 9/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.9296e-04 - root_mean_squared_error: 0.0139 - mae: 0.0110 - val_loss: 6.2606e-04 - val_root_mean_squared_error: 0.0250 - val_mae: 0.0230
# Epoch 10/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.8011e-04 - root_mean_squared_error: 0.0134 - mae: 0.0107 - val_loss: 4.8237e-04 - val_root_mean_squared_error: 0.0220 - val_mae: 0.0200
# Epoch 11/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.7527e-04 - root_mean_squared_error: 0.0132 - mae: 0.0106 - val_loss: 3.6218e-04 - val_root_mean_squared_error: 0.0190 - val_mae: 0.0170
# Epoch 12/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.6778e-04 - root_mean_squared_error: 0.0130 - mae: 0.0103INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 412ms/step - loss: 1.7858e-04 - root_mean_squared_error: 0.0134 - mae: 0.0107 - val_loss: 3.4011e-04 - val_root_mean_squared_error: 0.0184 - val_mae: 0.0164
# Epoch 13/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.7028e-04 - root_mean_squared_error: 0.0130 - mae: 0.0104 - val_loss: 3.8174e-04 - val_root_mean_squared_error: 0.0195 - val_mae: 0.0176
# Epoch 14/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.5758e-04 - root_mean_squared_error: 0.0126 - mae: 0.0100 - val_loss: 4.3522e-04 - val_root_mean_squared_error: 0.0209 - val_mae: 0.0189
# Epoch 15/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.5440e-04 - root_mean_squared_error: 0.0124 - mae: 0.0098 - val_loss: 4.4555e-04 - val_root_mean_squared_error: 0.0211 - val_mae: 0.0191
# Epoch 16/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.5196e-04 - root_mean_squared_error: 0.0123 - mae: 0.0097 - val_loss: 4.0301e-04 - val_root_mean_squared_error: 0.0201 - val_mae: 0.0181
# Epoch 17/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.4687e-04 - root_mean_squared_error: 0.0121 - mae: 0.0095 - val_loss: 3.6503e-04 - val_root_mean_squared_error: 0.0191 - val_mae: 0.0171
# Epoch 18/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.4645e-04 - root_mean_squared_error: 0.0121 - mae: 0.0095INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 407ms/step - loss: 1.4221e-04 - root_mean_squared_error: 0.0119 - mae: 0.0093 - val_loss: 3.0530e-04 - val_root_mean_squared_error: 0.0175 - val_mae: 0.0154
# Epoch 19/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.4654e-04 - root_mean_squared_error: 0.0121 - mae: 0.0097INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 415ms/step - loss: 1.3864e-04 - root_mean_squared_error: 0.0118 - mae: 0.0092 - val_loss: 2.2450e-04 - val_root_mean_squared_error: 0.0150 - val_mae: 0.0129
# Epoch 20/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.4510e-04 - root_mean_squared_error: 0.0120 - mae: 0.0097INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 657ms/step - loss: 1.4543e-04 - root_mean_squared_error: 0.0121 - mae: 0.0095 - val_loss: 2.0559e-04 - val_root_mean_squared_error: 0.0143 - val_mae: 0.0122
# Epoch 21/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.4290e-04 - root_mean_squared_error: 0.0120 - mae: 0.0094 - val_loss: 2.1873e-04 - val_root_mean_squared_error: 0.0148 - val_mae: 0.0127
# Epoch 22/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.3421e-04 - root_mean_squared_error: 0.0116 - mae: 0.0090 - val_loss: 2.4860e-04 - val_root_mean_squared_error: 0.0158 - val_mae: 0.0137
# Epoch 23/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2893e-04 - root_mean_squared_error: 0.0114 - mae: 0.0088 - val_loss: 2.8667e-04 - val_root_mean_squared_error: 0.0169 - val_mae: 0.0148
# Epoch 24/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2903e-04 - root_mean_squared_error: 0.0114 - mae: 0.0088 - val_loss: 2.9989e-04 - val_root_mean_squared_error: 0.0173 - val_mae: 0.0152
# Epoch 25/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3193e-04 - root_mean_squared_error: 0.0115 - mae: 0.0090 - val_loss: 2.8447e-04 - val_root_mean_squared_error: 0.0169 - val_mae: 0.0148
# Epoch 26/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2752e-04 - root_mean_squared_error: 0.0113 - mae: 0.0088 - val_loss: 2.1108e-04 - val_root_mean_squared_error: 0.0145 - val_mae: 0.0124
# Epoch 27/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.4402e-04 - root_mean_squared_error: 0.0120 - mae: 0.0090INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 417ms/step - loss: 1.2067e-04 - root_mean_squared_error: 0.0110 - mae: 0.0084 - val_loss: 1.5061e-04 - val_root_mean_squared_error: 0.0123 - val_mae: 0.0099
# Epoch 28/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0476e-04 - root_mean_squared_error: 0.0102 - mae: 0.0079INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 421ms/step - loss: 1.3383e-04 - root_mean_squared_error: 0.0116 - mae: 0.0089 - val_loss: 1.3509e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0090
# Epoch 29/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.4281e-04 - root_mean_squared_error: 0.0120 - mae: 0.0093 - val_loss: 1.3780e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0092
# Epoch 30/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.3042e-04 - root_mean_squared_error: 0.0114 - mae: 0.0088 - val_loss: 1.5896e-04 - val_root_mean_squared_error: 0.0126 - val_mae: 0.0103
# Epoch 31/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.1690e-04 - root_mean_squared_error: 0.0108 - mae: 0.0083 - val_loss: 2.1186e-04 - val_root_mean_squared_error: 0.0146 - val_mae: 0.0124
# Epoch 32/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2252e-04 - root_mean_squared_error: 0.0111 - mae: 0.0086 - val_loss: 2.2751e-04 - val_root_mean_squared_error: 0.0151 - val_mae: 0.0130
# Epoch 33/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2417e-04 - root_mean_squared_error: 0.0111 - mae: 0.0087 - val_loss: 1.9858e-04 - val_root_mean_squared_error: 0.0141 - val_mae: 0.0120
# Epoch 34/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1698e-04 - root_mean_squared_error: 0.0108 - mae: 0.0083 - val_loss: 1.6576e-04 - val_root_mean_squared_error: 0.0129 - val_mae: 0.0106
# Epoch 35/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1530e-04 - root_mean_squared_error: 0.0107 - mae: 0.0082 - val_loss: 1.4798e-04 - val_root_mean_squared_error: 0.0122 - val_mae: 0.0098
# Epoch 36/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1395e-04 - root_mean_squared_error: 0.0107 - mae: 0.0082 - val_loss: 1.6636e-04 - val_root_mean_squared_error: 0.0129 - val_mae: 0.0107
# Epoch 37/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1458e-04 - root_mean_squared_error: 0.0107 - mae: 0.0082 - val_loss: 1.9662e-04 - val_root_mean_squared_error: 0.0140 - val_mae: 0.0119
# Epoch 38/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1856e-04 - root_mean_squared_error: 0.0109 - mae: 0.0084 - val_loss: 1.9720e-04 - val_root_mean_squared_error: 0.0140 - val_mae: 0.0119
# Epoch 39/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1848e-04 - root_mean_squared_error: 0.0109 - mae: 0.0084 - val_loss: 1.7277e-04 - val_root_mean_squared_error: 0.0131 - val_mae: 0.0109
# Epoch 40/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.1298e-04 - root_mean_squared_error: 0.0106 - mae: 0.0081 - val_loss: 1.4787e-04 - val_root_mean_squared_error: 0.0122 - val_mae: 0.0098
# Epoch 41/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1262e-04 - root_mean_squared_error: 0.0106 - mae: 0.0081 - val_loss: 1.3914e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0093
# Epoch 42/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1449e-04 - root_mean_squared_error: 0.0107 - mae: 0.0081 - val_loss: 1.3730e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0092
# Epoch 43/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1412e-04 - root_mean_squared_error: 0.0107 - mae: 0.0081 - val_loss: 1.4578e-04 - val_root_mean_squared_error: 0.0121 - val_mae: 0.0097
# Epoch 44/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1112e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.4795e-04 - val_root_mean_squared_error: 0.0122 - val_mae: 0.0098
# Epoch 45/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1089e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.4644e-04 - val_root_mean_squared_error: 0.0121 - val_mae: 0.0097
# Epoch 46/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1047e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.5034e-04 - val_root_mean_squared_error: 0.0123 - val_mae: 0.0099
# Epoch 47/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.1051e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.5776e-04 - val_root_mean_squared_error: 0.0126 - val_mae: 0.0103
# Epoch 48/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1191e-04 - root_mean_squared_error: 0.0106 - mae: 0.0081 - val_loss: 1.6319e-04 - val_root_mean_squared_error: 0.0128 - val_mae: 0.0105
# Epoch 49/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1268e-04 - root_mean_squared_error: 0.0106 - mae: 0.0081 - val_loss: 1.5262e-04 - val_root_mean_squared_error: 0.0124 - val_mae: 0.0100
# Epoch 50/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0992e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.4085e-04 - val_root_mean_squared_error: 0.0119 - val_mae: 0.0094
# Epoch 51/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0992e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.3965e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0093
# Epoch 52/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1002e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.3813e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0092
# Epoch 53/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1097e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.3749e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0092
# Epoch 54/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1032e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.3915e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0093
# Epoch 55/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.2030e-04 - root_mean_squared_error: 0.0110 - mae: 0.0080INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 430ms/step - loss: 1.1053e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.3186e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0088
# Epoch 56/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.1642e-04 - root_mean_squared_error: 0.0108 - mae: 0.0086INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 425ms/step - loss: 1.1388e-04 - root_mean_squared_error: 0.0107 - mae: 0.0081 - val_loss: 1.3115e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0088
# Epoch 57/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1420e-04 - root_mean_squared_error: 0.0107 - mae: 0.0081 - val_loss: 1.3277e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0089
# Epoch 58/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.1159e-04 - root_mean_squared_error: 0.0106 - mae: 0.0080 - val_loss: 1.3885e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0093
# Epoch 59/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0916e-04 - root_mean_squared_error: 0.0104 - mae: 0.0079 - val_loss: 1.4033e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0094
# Epoch 60/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0893e-04 - root_mean_squared_error: 0.0104 - mae: 0.0079 - val_loss: 1.3960e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0094
# Epoch 61/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0890e-04 - root_mean_squared_error: 0.0104 - mae: 0.0079 - val_loss: 1.3926e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0093
# Epoch 62/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0871e-04 - root_mean_squared_error: 0.0104 - mae: 0.0079 - val_loss: 1.4544e-04 - val_root_mean_squared_error: 0.0121 - val_mae: 0.0097
# Epoch 63/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1002e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.4709e-04 - val_root_mean_squared_error: 0.0121 - val_mae: 0.0098
# Epoch 64/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0883e-04 - root_mean_squared_error: 0.0104 - mae: 0.0080 - val_loss: 1.3420e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0090
# Epoch 65/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0956e-04 - root_mean_squared_error: 0.0105 - mae: 0.0079 - val_loss: 1.3191e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0089
# Epoch 66/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1012e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.3634e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0092
# Epoch 67/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0877e-04 - root_mean_squared_error: 0.0104 - mae: 0.0079 - val_loss: 1.3960e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0094
# Epoch 68/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0985e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.3492e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0091
# Epoch 69/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0853e-04 - root_mean_squared_error: 0.0104 - mae: 0.0079 - val_loss: 1.5638e-04 - val_root_mean_squared_error: 0.0125 - val_mae: 0.0102
# Epoch 70/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1277e-04 - root_mean_squared_error: 0.0106 - mae: 0.0082 - val_loss: 1.7671e-04 - val_root_mean_squared_error: 0.0133 - val_mae: 0.0111
# Epoch 71/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1706e-04 - root_mean_squared_error: 0.0108 - mae: 0.0084 - val_loss: 1.5864e-04 - val_root_mean_squared_error: 0.0126 - val_mae: 0.0103
# Epoch 72/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1009e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.3756e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0093
# Epoch 73/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0769e-04 - root_mean_squared_error: 0.0104 - mae: 0.0079 - val_loss: 1.3177e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0089
# Epoch 74/100
# 1/3 [=========>....................] - ETA: 0s - loss: 9.4023e-05 - root_mean_squared_error: 0.0097 - mae: 0.0074INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 428ms/step - loss: 1.0853e-04 - root_mean_squared_error: 0.0104 - mae: 0.0079 - val_loss: 1.2963e-04 - val_root_mean_squared_error: 0.0114 - val_mae: 0.0087
# Epoch 75/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0984e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.3058e-04 - val_root_mean_squared_error: 0.0114 - val_mae: 0.0088
# Epoch 76/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0799e-04 - root_mean_squared_error: 0.0104 - mae: 0.0079 - val_loss: 1.3713e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0092
# Epoch 77/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0722e-04 - root_mean_squared_error: 0.0104 - mae: 0.0079 - val_loss: 1.3450e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0091
# Epoch 78/100
# 3/3 [==============================] - 0s 27ms/step - loss: 1.0740e-04 - root_mean_squared_error: 0.0104 - mae: 0.0079 - val_loss: 1.2996e-04 - val_root_mean_squared_error: 0.0114 - val_mae: 0.0088
# Epoch 79/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0907e-04 - root_mean_squared_error: 0.0104 - mae: 0.0082INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 425ms/step - loss: 1.0817e-04 - root_mean_squared_error: 0.0104 - mae: 0.0079 - val_loss: 1.2927e-04 - val_root_mean_squared_error: 0.0114 - val_mae: 0.0087
# Epoch 80/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0182e-04 - root_mean_squared_error: 0.0101 - mae: 0.0079INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 435ms/step - loss: 1.0925e-04 - root_mean_squared_error: 0.0105 - mae: 0.0079 - val_loss: 1.2808e-04 - val_root_mean_squared_error: 0.0113 - val_mae: 0.0086
# Epoch 81/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0926e-04 - root_mean_squared_error: 0.0105 - mae: 0.0079 - val_loss: 1.3536e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0091
# Epoch 82/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0829e-04 - root_mean_squared_error: 0.0104 - mae: 0.0080 - val_loss: 1.6898e-04 - val_root_mean_squared_error: 0.0130 - val_mae: 0.0108
# Epoch 83/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2185e-04 - root_mean_squared_error: 0.0110 - mae: 0.0087 - val_loss: 1.9285e-04 - val_root_mean_squared_error: 0.0139 - val_mae: 0.0118
# Epoch 84/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2764e-04 - root_mean_squared_error: 0.0113 - mae: 0.0089 - val_loss: 1.4757e-04 - val_root_mean_squared_error: 0.0121 - val_mae: 0.0098
# Epoch 85/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0762e-04 - root_mean_squared_error: 0.0104 - mae: 0.0079 - val_loss: 1.2985e-04 - val_root_mean_squared_error: 0.0114 - val_mae: 0.0086
# Epoch 86/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2581e-04 - root_mean_squared_error: 0.0112 - mae: 0.0086 - val_loss: 1.2954e-04 - val_root_mean_squared_error: 0.0114 - val_mae: 0.0086
# Epoch 87/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1717e-04 - root_mean_squared_error: 0.0108 - mae: 0.0082 - val_loss: 1.6744e-04 - val_root_mean_squared_error: 0.0129 - val_mae: 0.0107
# Epoch 88/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2536e-04 - root_mean_squared_error: 0.0112 - mae: 0.0088 - val_loss: 2.2388e-04 - val_root_mean_squared_error: 0.0150 - val_mae: 0.0129
# Epoch 89/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.3713e-04 - root_mean_squared_error: 0.0117 - mae: 0.0093 - val_loss: 1.4360e-04 - val_root_mean_squared_error: 0.0120 - val_mae: 0.0096
# Epoch 90/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0501e-04 - root_mean_squared_error: 0.0102 - mae: 0.0078 - val_loss: 1.3097e-04 - val_root_mean_squared_error: 0.0114 - val_mae: 0.0085
# Epoch 91/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.3020e-04 - root_mean_squared_error: 0.0114 - mae: 0.0088 - val_loss: 1.3222e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0086
# Epoch 92/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2440e-04 - root_mean_squared_error: 0.0112 - mae: 0.0086 - val_loss: 1.3446e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0091
# Epoch 93/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0629e-04 - root_mean_squared_error: 0.0103 - mae: 0.0079 - val_loss: 1.7367e-04 - val_root_mean_squared_error: 0.0132 - val_mae: 0.0110
# Epoch 94/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1724e-04 - root_mean_squared_error: 0.0108 - mae: 0.0084 - val_loss: 1.6143e-04 - val_root_mean_squared_error: 0.0127 - val_mae: 0.0105
# Epoch 95/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0329e-04 - root_mean_squared_error: 0.0102 - mae: 0.0079INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 421ms/step - loss: 1.0916e-04 - root_mean_squared_error: 0.0104 - mae: 0.0080 - val_loss: 1.2727e-04 - val_root_mean_squared_error: 0.0113 - val_mae: 0.0086
# Epoch 96/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1.1146e-04 - root_mean_squared_error: 0.0106 - mae: 0.0081 - val_loss: 1.3104e-04 - val_root_mean_squared_error: 0.0114 - val_mae: 0.0085
# Epoch 97/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2863e-04 - root_mean_squared_error: 0.0113 - mae: 0.0087 - val_loss: 1.2814e-04 - val_root_mean_squared_error: 0.0113 - val_mae: 0.0085
# Epoch 98/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1573e-04 - root_mean_squared_error: 0.0108 - mae: 0.0082 - val_loss: 1.3574e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0092
# Epoch 99/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0964e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.6059e-04 - val_root_mean_squared_error: 0.0127 - val_mae: 0.0104
# Epoch 100/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1188e-04 - root_mean_squared_error: 0.0106 - mae: 0.0082 - val_loss: 1.3913e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0094
# CPU times: user 19 s, sys: 510 ms, total: 19.5 s
# Wall time: 20.8 s

# %%
plt.figure(figsize=(10,6))
plt.plot(history_2.history['loss'])
plt.plot(history_2.history['val_loss'])
plt.title('pretrained CNN model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(history_2.history['mae'])
plt.plot(history_2.history['val_mae'])
plt.title('pretrained CNN model')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(history_2.history['root_mean_squared_error'])
plt.plot(history_2.history['val_root_mean_squared_error'])
plt.title('pretrained CNN model')
plt.ylabel('rmse')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
model_cnn_transfer = tf.keras.models.load_model("model_experiments/loaded_model")
model_cnn_transfer.evaluate(test_windows, test_labels)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2727e-04 - root_mean_squared_error: 0.0113 - mae: 0.0086
# [0.00012726533168461174, 0.011281194165349007, 0.008647440932691097]

# %%
model_cnn_preds = make_preds(model_cnn_transfer, test_windows)
len(model_cnn_preds), model_cnn_preds[:10]
# Out:
# (66, <tf.Tensor: shape=(10,), dtype=float32, numpy=
#  array([0.04899385, 0.05292315, 0.05794185, 0.05821697, 0.06042644,
#         0.0637238 , 0.06255518, 0.06449168, 0.06891129, 0.06394944],
#        dtype=float32)>)

# %%
model_cnn_results = evaluate_preds(y_true=tf.squeeze(test_labels), # reduce to right shape
                                 y_pred=model_cnn_preds)
model_cnn_results
# Out:
# {'mae': 0.008647441,
#  'mape': 14.754489,
#  'mase': 0.9535752,
#  'mse': 0.00012726533,
#  'rmse': 0.011281194}

# %%
plt.figure(figsize=(12,5))  
plt.plot(tf.squeeze(test_labels), color='blue', label='ET0 true')  
plt.plot(model_cnn_preds, color='red', label='ET0 predicted')  
plt.title('ET0 Forecasting')  
plt.xlabel('Date')  
plt.ylabel('ET0')  
plt.legend()
#plt.savefig("eto.png")
plt.show()

# %%
barWidth = 0.20
fig = plt.subplots(figsize =(8, 10))
 
# set height of bar
total_time = [23.5, 19.5]
wall_time = [23.6, 20.8]

 
# Set position of bar on X axis
br1 = np.arange(len(total_time))
br2 = [x + barWidth for x in br1]
 
# Make the plot
plt.bar(br1, total_time, color ='r', width = barWidth,
        edgecolor ='grey', label ='Total Time')
plt.bar(br2, wall_time, color ='g', width = barWidth,
        edgecolor ='grey', label ='Wall Time')
 
# Adding Xticks
plt.xlabel('models', fontweight ='bold', fontsize = 15)
plt.ylabel('time', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(total_time))],
        ['CNN model', 'pretrained CNN model'])
 
plt.legend()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x = ['Total Time', 'Wall Time']
time = [23.5, 23.6]
ax.bar(x,time,color='r')
plt.title('CNN model')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x = ['Total Time', 'Wall Time']
time = [19.5, 20.8]
ax.bar(x,time,color='g')
plt.title('Pretrained CNN model')
plt.show()
