# %% [markdown]
# # LSTM

# %% [markdown]
# ## Importing libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15,4)

import numpy as np
import pandas as pd
import plotly
import plotly.graph_objs as go

from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.metrics import mean_squared_error, mean_absolute_error
from plotly.offline import init_notebook_mode, iplot

# %% [markdown]
# ## Reading data

# %%
X_train = pd.read_csv('X_train.csv', index_col=['date'])
y_train = pd.read_csv('y_train.csv', index_col=['date'])

X_val = pd.read_csv('X_val.csv', index_col=['date'])
y_val = pd.read_csv('y_val.csv', index_col=['date'])

# %%
train_data = pd.concat([X_train, y_train], axis=1)
val_data = pd.concat([X_val, y_val], axis=1)

# %%
BATCH_SIZE = 32
N_INPUT = len(X_train)
N_FEATURES = len(X_train.columns)

# %%
trace0 = go.Scatter(
    x = train_data.index,
    y = train_data['reference_evapotranspiration'],
    name = 'Train'
)

trace1 = go.Scatter(
    x = val_data.index,
    y = val_data['reference_evapotranspiration'],
    name = 'Validation'
)

data = [trace0, trace1]

iplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="38df64f0-18f5-441e-b7a7-6ec2975a3d14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38df64f0-18f5-441e-b7a7-6ec2975a3d14")) {                    Plotly.newPlot(                        "38df64f0-18f5-441e-b7a7-6ec2975a3d14",                        [{"name":"Train","x":["2017-01-01","2017-01-02","2017-01-03","2017-01-04","2017-01-05","2017-01-06","2017-01-07","2017-01-08","2017-01-09","2017-01-10","2017-01-11","2017-01-12","2017-01-13","2017-01-14","2017-01-15","2017-01-16","2017-01-17","2017-01-18","2017-01-19","2017-01-20","2017-01-21","2017-01-22","2017-01-23","2017-01-24","2017-01-25","2017-01-26","2017-01-27","2017-01-28","2017-01-29","2017-01-30","2017-01-31","2017-02-01","2017-02-02","2017-02-03","2017-02-04","2017-02-05","2017-02-06","2017-02-07","2017-02-08","2017-02-09","2017-02-10","2017-02-11","2017-02-12","2017-02-13","2017-02-14","2017-02-15","2017-02-16","2017-02-17","2017-02-18","2017-02-19","2017-02-20","2017-02-21","2017-02-22","2017-02-23","2017-02-24","2017-02-25","2017-02-26","2017-02-27","2017-02-28","2017-03-01","2017-03-02","2017-03-03","2017-03-04","2017-03-05","2017-03-06","2017-03-07","2017-03-08","2017-03-09","2017-03-10","2017-03-11","2017-03-12","2017-03-13","2017-03-14","2017-03-15","2017-03-16","2017-03-17","2017-03-18","2017-03-19","2017-03-20","2017-03-21","2017-03-22","2017-03-23","2017-03-24","2017-03-25","2017-03-26","2017-03-27","2017-03-28","2017-03-29","2017-03-30","2017-03-31","2017-04-01","2017-04-02","2017-04-03","2017-04-04","2017-04-05","2017-04-06","2017-04-07","2017-04-08","2017-04-09","2017-04-10","2017-04-11","2017-04-12","2017-04-13","2017-04-14","2017-04-15","2017-04-16","2017-04-17","2017-04-18","2017-04-19","2017-04-20","2017-04-21","2017-04-22","2017-04-23","2017-04-24","2017-04-25","2017-04-26","2017-04-27","2017-04-28","2017-04-29","2017-04-30","2017-05-01","2017-05-02","2017-05-03","2017-05-04","2017-05-05","2017-05-06","2017-05-07","2017-05-08","2017-05-09","2017-05-10","2017-05-11","2017-05-12","2017-05-13","2017-05-14","2017-05-15","2017-05-16","2017-05-17","2017-05-18","2017-05-19","2017-05-20","2017-05-21","2017-05-22","2017-05-23","2017-05-24","2017-05-25","2017-05-26","2017-05-27","2017-05-28","2017-05-29","2017-05-30","2017-05-31","2017-06-01","2017-06-02","2017-06-03","2017-06-04","2017-06-05","2017-06-06","2017-06-07","2017-06-08","2017-06-09","2017-06-10","2017-06-11","2017-06-12","2017-06-13","2017-06-14","2017-06-15","2017-06-16","2017-06-17","2017-06-18","2017-06-19","2017-06-20","2017-06-21","2017-06-22","2017-06-23","2017-06-24","2017-06-25","2017-06-26","2017-06-27","2017-06-28","2017-06-29","2017-06-30","2017-07-01","2017-07-02","2017-07-03","2017-07-04","2017-07-05","2017-07-06","2017-07-07","2017-07-08","2017-07-09","2017-07-10","2017-07-11","2017-07-12","2017-07-13","2017-07-14","2017-07-15","2017-07-16","2017-07-17","2017-07-18","2017-07-19","2017-07-20","2017-07-21","2017-07-22","2017-07-23","2017-07-24","2017-07-25","2017-07-26","2017-07-27","2017-07-28","2017-07-29","2017-07-30","2017-07-31","2017-08-01"],"y":[0.0585373667499999,0.0485320319583333,0.064638817125,0.0723622035,0.0483415317916666,0.0520071012083333,0.0421720670833333,0.056362937625,0.0497983688333333,0.0491749308333333,0.040022481125,0.061603525875,0.0535422692916666,0.05453691175,0.0515784663333333,0.0463444437083333,0.0727804297916666,0.0519752139166666,0.0434888700416666,0.0275477400416666,0.0480012325833333,0.0568660850416666,0.0490069833333333,0.0621102809583333,0.0574804377916666,0.069811514125,0.055917247875,0.0481949567083333,0.0638106683333333,0.06892562175,0.0429104647083333,0.048016376375,0.0640579883333333,0.0744080900416666,0.0825590733333333,0.06613952025,0.0751373087083333,0.0 ...

# %%
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
X, y = split_sequence(train_data['reference_evapotranspiration'].values, 5)

# %%
n_features = 1
n_steps = 5

# %%
X = X.reshape((X.shape[0], X.shape[1], n_features))

model = Sequential()
model.add((LSTM(50,
                dropout=0.2,
                recurrent_dropout=0.2,
                activation='relu',
                input_shape=(n_steps, n_features))))
model.add(Dense(1))

model.compile(optimizer='adam', 
              loss='mean_absolute_error', 
              metrics=[mean_absolute_error, mean_squared_error])

# %%
model.fit(X, y, epochs=40, verbose=1)
# Out:
# Epoch 1/40
# 7/7 [==============================] - 3s 6ms/step - loss: 0.0213 - mean_absolute_error: 0.0213 - mean_squared_error: 7.0450e-04
# Epoch 2/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0127 - mean_absolute_error: 0.0127 - mean_squared_error: 2.4410e-04
# Epoch 3/40
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0124 - mean_absolute_error: 0.0124 - mean_squared_error: 2.3603e-04
# Epoch 4/40
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0117 - mean_absolute_error: 0.0117 - mean_squared_error: 2.2805e-04
# Epoch 5/40
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - mean_squared_error: 2.1275e-04
# Epoch 6/40
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0116 - mean_absolute_error: 0.0116 - mean_squared_error: 2.1354e-04
# Epoch 7/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0112 - mean_absolute_error: 0.0112 - mean_squared_error: 2.0716e-04
# Epoch 8/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0113 - mean_absolute_error: 0.0113 - mean_squared_error: 2.1024e-04
# Epoch 9/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - mean_squared_error: 1.9540e-04
# Epoch 10/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0108 - mean_absolute_error: 0.0108 - mean_squared_error: 1.9464e-04
# Epoch 11/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0110 - mean_absolute_error: 0.0110 - mean_squared_error: 2.0040e-04
# Epoch 12/40
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0109 - mean_absolute_error: 0.0109 - mean_squared_error: 2.0400e-04
# Epoch 13/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0106 - mean_absolute_error: 0.0106 - mean_squared_error: 1.7745e-04
# Epoch 14/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - mean_squared_error: 1.7605e-04
# Epoch 15/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0101 - mean_absolute_error: 0.0101 - mean_squared_error: 1.6560e-04
# Epoch 16/40
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0103 - mean_absolute_error: 0.0103 - mean_squared_error: 1.7531e-04
# Epoch 17/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - mean_squared_error: 1.8766e-04
# Epoch 18/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0105 - mean_absolute_error: 0.0105 - mean_squared_error: 1.9129e-04
# Epoch 19/40
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0100 - mean_absolute_error: 0.0100 - mean_squared_error: 1.5597e-04
# Epoch 20/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0100 - mean_absolute_error: 0.0100 - mean_squared_error: 1.6662e-04
# Epoch 21/40
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0095 - mean_absolute_error: 0.0095 - mean_squared_error: 1.4518e-04
# Epoch 22/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0101 - mean_absolute_error: 0.0101 - mean_squared_error: 1.7196e-04
# Epoch 23/40
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0096 - mean_absolute_error: 0.0096 - mean_squared_error: 1.5047e-04
# Epoch 24/40
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0094 - mean_absolute_error: 0.0094 - mean_squared_error: 1.4695e-04
# Epoch 25/40
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0096 - mean_absolute_error: 0.0096 - mean_squared_error: 1.6669e-04
# Epoch 26/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0101 - mean_absolute_error: 0.0101 - mean_squared_error: 1.5987e-04
# Epoch 27/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0094 - mean_absolute_error: 0.0094 - mean_squared_error: 1.5310e-04
# Epoch 28/40
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0097 - mean_absolute_error: 0.0097 - mean_squared_error: 1.5263e-04
# Epoch 29/40
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0097 - mean_absolute_error: 0.0097 - mean_squared_error: 1.5778e-04
# Epoch 30/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0098 - mean_absolute_error: 0.0098 - mean_squared_error: 1.6365e-04
# Epoch 31/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0101 - mean_absolute_error: 0.0101 - mean_squared_error: 1.6447e-04
# Epoch 32/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0095 - mean_absolute_error: 0.0095 - mean_squared_error: 1.5210e-04
# Epoch 33/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0097 - mean_absolute_error: 0.0097 - mean_squared_error: 1.4936e-04
# Epoch 34/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0091 - mean_absolute_error: 0.0091 - mean_squared_error: 1.4061e-04
# Epoch 35/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0090 - mean_absolute_error: 0.0090 - mean_squared_error: 1.4541e-04
# Epoch 36/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0088 - mean_absolute_error: 0.0088 - mean_squared_error: 1.3039e-04
# Epoch 37/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0086 - mean_absolute_error: 0.0086 - mean_squared_error: 1.3150e-04
# Epoch 38/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0093 - mean_absolute_error: 0.0093 - mean_squared_error: 1.4264e-04
# Epoch 39/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0093 - mean_absolute_error: 0.0093 - mean_squared_error: 1.4571e-04
# Epoch 40/40
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0092 - mean_absolute_error: 0.0092 - mean_squared_error: 1.4229e-04

# %%
X_val, y_val = split_sequence(val_data['reference_evapotranspiration'].values, 5)

# %%
X_val = X_val.reshape((X_val.shape[0], X_val.shape[1], n_features))

# %%
y_pred = model.predict(X_val, verbose=1)
# Out:
# 2/2 [==============================] - 0s 5ms/step

# %%
y_pred = np.array([val for sublist in y_pred for val in sublist])

# %%
mae = mean_absolute_error(y_val, y_pred)
mae
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.012039288>

# %%
mse = mean_squared_error(y_val, y_pred)
mse
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.00020180189>

# %%
plt.figure(figsize=(12,5))  
plt.plot(y_val, color='blue', label='ET0 true')  
plt.plot(y_pred, color='red', label='ET0 predicted')  
plt.title('ET0 Forecasting')  
plt.xlabel('Date')  
plt.ylabel('ET0')  
plt.legend()
#plt.savefig("eto.png")
plt.show()

# %%
X_test = pd.read_csv('X_test.csv', index_col=['date'])
y_test = pd.read_csv('y_test.csv', index_col=['date'])

test_data = pd.concat([X_test, y_test], axis=1)

# %%
X_test, y_test = split_sequence(test_data['reference_evapotranspiration'].values, 5)

X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], n_features))

# %%
y_pred_test = model.predict(X_test, verbose=1)
# Out:
# 2/2 [==============================] - 0s 6ms/step

# %%
y_pred_test = np.array([val for sublist in y_pred_test for val in sublist])

# %%
mae_test = mean_absolute_error(y_test, y_pred_test)
mae_test
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.015868917>

# %%
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))
rmse_test
# Out:
# 0.01804758

# %% [markdown]
# * MAE = 0.015868917
# * RMSE = 0.01804758
