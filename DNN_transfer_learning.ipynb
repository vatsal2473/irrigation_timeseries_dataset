# %% [markdown]
# [Open in colab](https://colab.research.google.com/drive/1HyuvwQkOl2LxlJD4rrhn7pUtDoZ3tNrR?usp=sharing)

# %% [markdown]
# # DNN

# %% [markdown]
# ## Importing libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15,4)

import numpy as np
import pandas as pd
import plotly
import plotly.graph_objs as go

import tensorflow as tf
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.metrics import mean_squared_error, mean_absolute_error
from plotly.offline import init_notebook_mode, iplot

# %% [markdown]
# ## Reading data

# %%
X_train = pd.read_csv('X_train_complete.csv', index_col=['date'])
y_train = pd.read_csv('y_train_complete.csv', index_col=['date'])

X_test = pd.read_csv('X_test.csv', index_col=['date'])
y_test = pd.read_csv('y_test.csv', index_col=['date'])

# %%
train_data = pd.concat([X_train, y_train], axis=1)
test_data = pd.concat([X_test, y_test], axis=1)

# %%
full_data = pd.concat([train_data, test_data], axis=0)

# %%
full_data
# Out:
#             maximum_atmospheric_pressure  minimum_atmospheric_pressure  \
# date
# 2017-01-01                    617.799658                    599.803362
# 2017-01-02                    620.147296                    599.795100
# 2017-01-03                    620.212662                    599.817608
# 2017-01-04                    616.165437                    599.787975
# 2017-01-05                    619.378317                    599.802992
# ...                                  ...                           ...
# 2017-11-25                    617.598033                    599.774778
# 2017-11-26                    618.306160                    599.760990
# 2017-11-27                    618.387980                    599.769210
# 2017-11-28                    615.830622                    599.787011
# 2017-11-29                    617.115633                    599.775633
#
#             precipitation  maximum_air_temperature  minimum_air_temperature  \
# date
# 2017-01-01       0.000000                30.318042                28.722792
# 2017-01-02       0.000000                29.630875                28.269417
# 2017-01-03       0.000000                29.409917                28.005583
# 2017-01-04       0.105833                29.755875                28.265958
# 2017-01-05       0.000000                28.977792                27.437292
# ...                   ...                      ...                      ...
# 2017-11-25       0.000000                26.162222                25.260667
# 2017-11-26       0.000000                25.160600                24.471200
# 2017-11-27       0.000000                26.168600                25.124500
# 2017-11-28       0.000000                26.670000                25.588444
# 2017-11-29       0.000000                27.488417                26.432167
#
#             maximum_relative_humidity  minimum_relative_humidity  \
# date
# 2017-01-01                  66.477167                  60.174625
# 2017-01-02                  67.488500                  61.223083
# 2017-01-03                  70.001792                  64.124500
# 2017-01-04                  69.879833                  63.227792
# 2017-01-05                  70.608750                  64.299542
# ...                               ...                        ...
# 2017-11-25                  77.043111                  72.860000
# 2017-11-26                  80.193500                  75.632100
# 2017-11-27                  79.476900                  73.358900
# 2017-11-28                  74.379444                  68.880667
# 2017-11-29                  72.656833                  67.606917
#
#             total_solar_radiation  maximum_temperature  minimum_temperature  \
# date
# 2017-01-01            2145.823333            21.408342            20.312011
# 2017-01-02            1951.849667            21.264383            20.061859
# 2017-01-03            2104.909208            21.635286            20.695279
# 2017-01-04            1963.737875            21.848865            20.813229
# 2017-01-05            2001.953125            21.344600            20.438310
# ...                           ...                  ...                  ...
# 2017-11-25            2500.997667            21.037083            20.542369
# 2017-11-26            2459.780530            20.800224            20.227300
# 2017-11-27            2507.158000            21.240160            20.642043
# 2017-11-28            2315.237867            20.622838            20.113804
# 2017-11-29            2247.963342            21.044991            20.470040
#
#             average_air_temperature  average_relative_humidity  wind_speed  \
# date
# 2017-01-01                29.543242                  63.174958    1.132543
# 2017-01-02                28.910676                  64.436735    1.087624
# 2017-01-03                28.650169                  67.002696    1.630787
# 2017-01-04                28.881102                  66.914866    1.921033
# 2017-01-05                28.167198                  67.434008    1.197141
# ...                             ...                        ...         ...
# 2017-11-25                25.666700                  75.260879    1.739529
# 2017-11-26                24.812676                  77.932516    1.118328
# 2017-11-27                25.678424                  76.354913    1.606195
# 2017-11-28                26.121304                  71.750116    1.845503
# 2017-11-29                26.989442                  70.110090    1.822953
#
#             total_solar_radiation.1  reference_evapotranspiration
# date
# 2017-01-01                 5.960620                      0.058537
# 2017-01-02                 5.421805                      0.048532
# 2017-01-03                 5.846970                      0.064639
# 2017-01-04                 5.454827                      0.072362
# 2017-01-05                 5.560981                      0.048342
# ...                             ...                           ...
# 2017-11-25                 6.947216                      0.035565
# 2017-11-26                 7.850408                      0.025799
# 2017-11-27                 7.510718                      0.034958
# 2017-11-28                 8.251289                      0.042553
# 2017-11-29                 7.229652                      0.049749
#
# [334 rows x 15 columns]

# %%
BATCH_SIZE = 32
N_INPUT = len(X_train)
N_FEATURES = len(X_train.columns)

# %%
trace0 = go.Scatter(
    x = train_data.index,
    y = train_data['reference_evapotranspiration'],
    name = 'Train'
)

trace1 = go.Scatter(
    x = test_data.index,
    y = test_data['reference_evapotranspiration'],
    name = 'Validation'
)

data = [trace0, trace1]

iplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9cc7c2ae-aac8-4fde-9049-6cd1c1b7d485" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9cc7c2ae-aac8-4fde-9049-6cd1c1b7d485")) {                    Plotly.newPlot(                        "9cc7c2ae-aac8-4fde-9049-6cd1c1b7d485",                        [{"name":"Train","x":["2017-01-01","2017-01-02","2017-01-03","2017-01-04","2017-01-05","2017-01-06","2017-01-07","2017-01-08","2017-01-09","2017-01-10","2017-01-11","2017-01-12","2017-01-13","2017-01-14","2017-01-15","2017-01-16","2017-01-17","2017-01-18","2017-01-19","2017-01-20","2017-01-21","2017-01-22","2017-01-23","2017-01-24","2017-01-25","2017-01-26","2017-01-27","2017-01-28","2017-01-29","2017-01-30","2017-01-31","2017-02-01","2017-02-02","2017-02-03","2017-02-04","2017-02-05","2017-02-06","2017-02-07","2017-02-08","2017-02-09","2017-02-10","2017-02-11","2017-02-12","2017-02-13","2017-02-14","2017-02-15","2017-02-16","2017-02-17","2017-02-18","2017-02-19","2017-02-20","2017-02-21","2017-02-22","2017-02-23","2017-02-24","2017-02-25","2017-02-26","2017-02-27","2017-02-28","2017-03-01","2017-03-02","2017-03-03","2017-03-04","2017-03-05","2017-03-06","2017-03-07","2017-03-08","2017-03-09","2017-03-10","2017-03-11","2017-03-12","2017-03-13","2017-03-14","2017-03-15","2017-03-16","2017-03-17","2017-03-18","2017-03-19","2017-03-20","2017-03-21","2017-03-22","2017-03-23","2017-03-24","2017-03-25","2017-03-26","2017-03-27","2017-03-28","2017-03-29","2017-03-30","2017-03-31","2017-04-01","2017-04-02","2017-04-03","2017-04-04","2017-04-05","2017-04-06","2017-04-07","2017-04-08","2017-04-09","2017-04-10","2017-04-11","2017-04-12","2017-04-13","2017-04-14","2017-04-15","2017-04-16","2017-04-17","2017-04-18","2017-04-19","2017-04-20","2017-04-21","2017-04-22","2017-04-23","2017-04-24","2017-04-25","2017-04-26","2017-04-27","2017-04-28","2017-04-29","2017-04-30","2017-05-01","2017-05-02","2017-05-03","2017-05-04","2017-05-05","2017-05-06","2017-05-07","2017-05-08","2017-05-09","2017-05-10","2017-05-11","2017-05-12","2017-05-13","2017-05-14","2017-05-15","2017-05-16","2017-05-17","2017-05-18","2017-05-19","2017-05-20","2017-05-21","2017-05-22","2017-05-23","2017-05-24","2017-05-25","2017-05-26","2017-05-27","2017-05-28","2017-05-29","2017-05-30","2017-05-31","2017-06-01","2017-06-02","2017-06-03","2017-06-04","2017-06-05","2017-06-06","2017-06-07","2017-06-08","2017-06-09","2017-06-10","2017-06-11","2017-06-12","2017-06-13","2017-06-14","2017-06-15","2017-06-16","2017-06-17","2017-06-18","2017-06-19","2017-06-20","2017-06-21","2017-06-22","2017-06-23","2017-06-24","2017-06-25","2017-06-26","2017-06-27","2017-06-28","2017-06-29","2017-06-30","2017-07-01","2017-07-02","2017-07-03","2017-07-04","2017-07-05","2017-07-06","2017-07-07","2017-07-08","2017-07-09","2017-07-10","2017-07-11","2017-07-12","2017-07-13","2017-07-14","2017-07-15","2017-07-16","2017-07-17","2017-07-18","2017-07-19","2017-07-20","2017-07-21","2017-07-22","2017-07-23","2017-07-24","2017-07-25","2017-07-26","2017-07-27","2017-07-28","2017-07-29","2017-07-30","2017-07-31","2017-08-01","2017-08-02","2017-08-03","2017-08-04","2017-08-05","2017-08-06","2017-08-07","2017-08-08","2017-08-09","2017-08-10","2017-08-11","2017-08-12","2017-08-13","2017-08-14","2017-08-15","2017-08-16","2017-08-17","2017-08-18","2017-08-19","2017-08-20","2017-08-21","2017-08-22","2017-08-23","2017-08-24","2017-08-25","2017-08-26","2017-08-27","2017-08-28","2017-08-29","2017-08-30","2017-08-31","2017-09-01","2017-09-02","2017-09-03","2017-09-04","2017-09-05","2017-09-06","2017-09-07","2017-09-08","2017-09-09","2017-09-10","2017-09-11","2017-09-12","2017-09-13","2017-09-14","2017-09-15","2017-09-16","2017-09-17","2017-09-18","2017-09-19","2017-09-20","2017-09-21", ...

# %%
# MASE implemented courtesy of sktime - https://github.com/alan-turing-institute/sktime/blob/ee7a06843a44f4aaec7582d847e36073a9ab0566/sktime/performance_metrics/forecasting/_functions.py#L16
def mean_absolute_scaled_error(y_true, y_pred):
  """
  Implement MASE (assuming no seasonality of data).
  """
  mae = tf.reduce_mean(tf.abs(y_true - y_pred))

  # Find MAE of naive forecast (no seasonality)
  mae_naive_no_season = tf.reduce_mean(tf.abs(y_true[1:] - y_true[:-1])) # our seasonality is 1 day (hence the shifting of 1 day)

  return mae / mae_naive_no_season

# %%
def evaluate_preds(y_true, y_pred):
  # Make sure float32 (for metric calculations)
  y_true = tf.cast(y_true, dtype=tf.float32)
  y_pred = tf.cast(y_pred, dtype=tf.float32)

  # Calculate various metrics
  mae = tf.keras.metrics.mean_absolute_error(y_true, y_pred)
  mse = tf.keras.metrics.mean_squared_error(y_true, y_pred) # puts and emphasis on outliers (all errors get squared)
  rmse = tf.sqrt(mse)
  mape = tf.keras.metrics.mean_absolute_percentage_error(y_true, y_pred)
  mase = mean_absolute_scaled_error(y_true, y_pred)
  
  return {"mae": mae.numpy(),
          "mse": mse.numpy(),
          "rmse": rmse.numpy(),
          "mape": mape.numpy(),
          "mase": mase.numpy()}

# %%
HORIZON = 1
WINDOW_SIZE = 7

# %%
# Create function to label windowed data
def get_labelled_windows(x, horizon=1):
  """
  Creates labels for windowed dataset.

  E.g. if horizon=1 (default)
  Input: [1, 2, 3, 4, 5, 6] -> Output: ([1, 2, 3, 4, 5], [6])
  """
  return x[:, :-horizon], x[:, -horizon:]

# %%
# Test out the window labelling function
test_window, test_label = get_labelled_windows(tf.expand_dims(tf.range(8)+1, axis=0), horizon=HORIZON)
print(f"Window: {tf.squeeze(test_window).numpy()} -> Label: {tf.squeeze(test_label).numpy()}")
# Out:
# Window: [1 2 3 4 5 6 7] -> Label: 8

# %%
# Create function to view NumPy arrays as windows 
def make_windows(x, window_size=7, horizon=1):
  """
  Turns a 1D array into a 2D array of sequential windows of window_size.
  """
  # 1. Create a window of specific window_size (add the horizon on the end for later labelling)
  window_step = np.expand_dims(np.arange(window_size+horizon), axis=0)
  # print(f"Window step:\n {window_step}")

  # 2. Create a 2D array of multiple window steps (minus 1 to account for 0 indexing)
  window_indexes = window_step + np.expand_dims(np.arange(len(x)-(window_size+horizon-1)), axis=0).T # create 2D array of windows of size window_size
  # print(f"Window indexes:\n {window_indexes[:3], window_indexes[-3:], window_indexes.shape}")

  # 3. Index on the target array (time series) with 2D array of multiple window steps
  windowed_array = x[window_indexes]

  # 4. Get the labelled windows
  windows, labels = get_labelled_windows(windowed_array, horizon=horizon)

  return windows, labels

# %%
timesteps = full_data.index.to_numpy()
re = full_data["reference_evapotranspiration"].to_numpy()

# %%
full_windows, full_labels = make_windows(re, window_size=WINDOW_SIZE, horizon=HORIZON)
len(full_windows), len(full_labels)
# Out:
# (327, 327)

# %%
# View the first 3 windows/labels
for i in range(3):
  print(f"Window: {full_windows[i]} -> Label: {full_labels[i]}")
# Out:
# Window: [0.05853737 0.04853203 0.06463882 0.0723622  0.04834153 0.0520071
#  0.04217207] -> Label: [0.05636294]
# Window: [0.04853203 0.06463882 0.0723622  0.04834153 0.0520071  0.04217207
#  0.05636294] -> Label: [0.04979837]
# Window: [0.06463882 0.0723622  0.04834153 0.0520071  0.04217207 0.05636294
#  0.04979837] -> Label: [0.04917493]

# %%
# Make the train/test splits
def make_train_test_splits(windows, labels, test_split=0.2):
  """
  Splits matching pairs of windows and labels into train and test splits.
  """
  split_size = int(len(windows) * (1-test_split)) # this will default to 80% train/20% test
  train_windows = windows[:split_size]
  train_labels = labels[:split_size]
  test_windows = windows[split_size:]
  test_labels = labels[split_size:]
  return train_windows, test_windows, train_labels, test_labels

# %%
train_windows, test_windows, train_labels, test_labels = make_train_test_splits(full_windows, full_labels)
len(train_windows), len(test_windows), len(train_labels), len(test_labels)
# Out:
# (261, 66, 261, 66)

# %%
import os

# Create a function to implement a ModelCheckpoint callback with a specific filename 
def create_model_checkpoint(model_name, save_path="model_experiments"):
  return tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(save_path, model_name), # create filepath to save model
                                            verbose=0, # only output a limited amount of text
                                            save_best_only=True) # save only the best model to file

# %%
train_windows.shape, train_labels.shape
# Out:
# ((261, 7), (261, 1))

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', mode = 'min',
                                                  verbose = 1, patience = 20)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                                                 patience=5, min_lr=0.00001)

# %%
# %%time
import tensorflow as tf
from tensorflow.keras import layers

# Set random seed for as reproducible results as possible
tf.random.set_seed(42)

# Construct model
model_dnn = tf.keras.Sequential([
  layers.Dense(128, activation="relu"),
  layers.Dense(HORIZON, activation="linear") # linear activation is the same as having no activation                        
], name="model_1_dense") # give the model a name so we can save it

rmse = tf.keras.metrics.RootMeanSquaredError()

# Compile model
model_dnn.compile(loss="mean_squared_error",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=[rmse,'mae']) # we don't necessarily need this when the loss function is already MAE

# Fit model
history_1 = model_dnn.fit(x=train_windows, # train windows of 7 timesteps
              y=train_labels, # horizon value of 1 (using the previous 7 timesteps to predict next day)
              epochs=100,
              verbose=1,
              batch_size=128,
              validation_data=(test_windows, test_labels),
              callbacks=[create_model_checkpoint(model_name=model_dnn.name)])
# Out:
# Epoch 1/100
# 1/3 [=========>....................] - ETA: 2s - loss: 6.3520e-04 - root_mean_squared_error: 0.0252 - mae: 0.0216INFO:tensorflow:Assets written to: model_experiments/model_1_dense/assets
# 3/3 [==============================] - 4s 1s/step - loss: 4.6964e-04 - root_mean_squared_error: 0.0217 - mae: 0.0177 - val_loss: 2.5419e-04 - val_root_mean_squared_error: 0.0159 - val_mae: 0.0137
# Epoch 2/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.5901e-04 - root_mean_squared_error: 0.0126 - mae: 0.0102INFO:tensorflow:Assets written to: model_experiments/model_1_dense/assets
# 3/3 [==============================] - 2s 819ms/step - loss: 2.0985e-04 - root_mean_squared_error: 0.0145 - mae: 0.0117 - val_loss: 1.4504e-04 - val_root_mean_squared_error: 0.0120 - val_mae: 0.0092
# Epoch 3/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2.1280e-04 - root_mean_squared_error: 0.0146 - mae: 0.0119 - val_loss: 2.5051e-04 - val_root_mean_squared_error: 0.0158 - val_mae: 0.0137
# Epoch 4/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.4330e-04 - root_mean_squared_error: 0.0120 - mae: 0.0093 - val_loss: 4.3682e-04 - val_root_mean_squared_error: 0.0209 - val_mae: 0.0189
# Epoch 5/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1.6092e-04 - root_mean_squared_error: 0.0127 - mae: 0.0099 - val_loss: 3.8867e-04 - val_root_mean_squared_error: 0.0197 - val_mae: 0.0177
# Epoch 6/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1.4598e-04 - root_mean_squared_error: 0.0121 - mae: 0.0094 - val_loss: 2.4866e-04 - val_root_mean_squared_error: 0.0158 - val_mae: 0.0136
# Epoch 7/100
# 3/3 [==============================] - 0s 28ms/step - loss: 1.2914e-04 - root_mean_squared_error: 0.0114 - mae: 0.0087 - val_loss: 1.6110e-04 - val_root_mean_squared_error: 0.0127 - val_mae: 0.0103
# Epoch 8/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.4099e-04 - root_mean_squared_error: 0.0119 - mae: 0.0093INFO:tensorflow:Assets written to: model_experiments/model_1_dense/assets
# 3/3 [==============================] - 2s 816ms/step - loss: 1.3886e-04 - root_mean_squared_error: 0.0118 - mae: 0.0091 - val_loss: 1.4120e-04 - val_root_mean_squared_error: 0.0119 - val_mae: 0.0093
# Epoch 9/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1.4218e-04 - root_mean_squared_error: 0.0119 - mae: 0.0092 - val_loss: 1.5231e-04 - val_root_mean_squared_error: 0.0123 - val_mae: 0.0099
# Epoch 10/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.2490e-04 - root_mean_squared_error: 0.0112 - mae: 0.0085 - val_loss: 1.9009e-04 - val_root_mean_squared_error: 0.0138 - val_mae: 0.0116
# Epoch 11/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1838e-04 - root_mean_squared_error: 0.0109 - mae: 0.0083 - val_loss: 2.0139e-04 - val_root_mean_squared_error: 0.0142 - val_mae: 0.0120
# Epoch 12/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1.1926e-04 - root_mean_squared_error: 0.0109 - mae: 0.0084 - val_loss: 1.8659e-04 - val_root_mean_squared_error: 0.0137 - val_mae: 0.0115
# Epoch 13/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1.1629e-04 - root_mean_squared_error: 0.0108 - mae: 0.0083 - val_loss: 1.5440e-04 - val_root_mean_squared_error: 0.0124 - val_mae: 0.0100
# Epoch 14/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0840e-04 - root_mean_squared_error: 0.0104 - mae: 0.0082INFO:tensorflow:Assets written to: model_experiments/model_1_dense/assets
# 3/3 [==============================] - 1s 435ms/step - loss: 1.1466e-04 - root_mean_squared_error: 0.0107 - mae: 0.0081 - val_loss: 1.3779e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0092
# Epoch 15/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.2477e-04 - root_mean_squared_error: 0.0112 - mae: 0.0087INFO:tensorflow:Assets written to: model_experiments/model_1_dense/assets
# 3/3 [==============================] - 1s 471ms/step - loss: 1.1496e-04 - root_mean_squared_error: 0.0107 - mae: 0.0081 - val_loss: 1.3660e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0091
# Epoch 16/100
# 3/3 [==============================] - 0s 68ms/step - loss: 1.1358e-04 - root_mean_squared_error: 0.0107 - mae: 0.0080 - val_loss: 1.4342e-04 - val_root_mean_squared_error: 0.0120 - val_mae: 0.0095
# Epoch 17/100
# 3/3 [==============================] - 0s 62ms/step - loss: 1.1067e-04 - root_mean_squared_error: 0.0105 - mae: 0.0080 - val_loss: 1.6477e-04 - val_root_mean_squared_error: 0.0128 - val_mae: 0.0105
# Epoch 18/100
# 3/3 [==============================] - 0s 78ms/step - loss: 1.1383e-04 - root_mean_squared_error: 0.0107 - mae: 0.0082 - val_loss: 1.4614e-04 - val_root_mean_squared_error: 0.0121 - val_mae: 0.0097
# Epoch 19/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.1145e-04 - root_mean_squared_error: 0.0106 - mae: 0.0083INFO:tensorflow:Assets written to: model_experiments/model_1_dense/assets
# 3/3 [==============================] - 1s 459ms/step - loss: 1.0898e-04 - root_mean_squared_error: 0.0104 - mae: 0.0078 - val_loss: 1.2733e-04 - val_root_mean_squared_error: 0.0113 - val_mae: 0.0084
# Epoch 20/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.1211e-04 - root_mean_squared_error: 0.0106 - mae: 0.0084INFO:tensorflow:Assets written to: model_experiments/model_1_dense/assets
# 3/3 [==============================] - 1s 269ms/step - loss: 1.1838e-04 - root_mean_squared_error: 0.0109 - mae: 0.0083 - val_loss: 1.2646e-04 - val_root_mean_squared_error: 0.0112 - val_mae: 0.0085
# Epoch 21/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1223e-04 - root_mean_squared_error: 0.0106 - mae: 0.0080 - val_loss: 1.3493e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0091
# Epoch 22/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0559e-04 - root_mean_squared_error: 0.0103 - mae: 0.0077 - val_loss: 1.5505e-04 - val_root_mean_squared_error: 0.0125 - val_mae: 0.0100
# Epoch 23/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0732e-04 - root_mean_squared_error: 0.0104 - mae: 0.0079 - val_loss: 1.6739e-04 - val_root_mean_squared_error: 0.0129 - val_mae: 0.0106
# Epoch 24/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0707e-04 - root_mean_squared_error: 0.0103 - mae: 0.0079 - val_loss: 1.5306e-04 - val_root_mean_squared_error: 0.0124 - val_mae: 0.0099
# Epoch 25/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0390e-04 - root_mean_squared_error: 0.0102 - mae: 0.0077 - val_loss: 1.4667e-04 - val_root_mean_squared_error: 0.0121 - val_mae: 0.0096
# Epoch 26/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0275e-04 - root_mean_squared_error: 0.0101 - mae: 0.0077 - val_loss: 1.3340e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0090
# Epoch 27/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.2455e-04 - root_mean_squared_error: 0.0112 - mae: 0.0081INFO:tensorflow:Assets written to: model_experiments/model_1_dense/assets
# 3/3 [==============================] - 1s 284ms/step - loss: 1.0357e-04 - root_mean_squared_error: 0.0102 - mae: 0.0076 - val_loss: 1.2534e-04 - val_root_mean_squared_error: 0.0112 - val_mae: 0.0084
# Epoch 28/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1.1763e-04 - root_mean_squared_error: 0.0108 - mae: 0.0082 - val_loss: 1.2781e-04 - val_root_mean_squared_error: 0.0113 - val_mae: 0.0085
# Epoch 29/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1638e-04 - root_mean_squared_error: 0.0108 - mae: 0.0083 - val_loss: 1.2570e-04 - val_root_mean_squared_error: 0.0112 - val_mae: 0.0086
# Epoch 30/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0425e-04 - root_mean_squared_error: 0.0102 - mae: 0.0077 - val_loss: 1.3759e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0092
# Epoch 31/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0238e-04 - root_mean_squared_error: 0.0101 - mae: 0.0076 - val_loss: 1.6082e-04 - val_root_mean_squared_error: 0.0127 - val_mae: 0.0102
# Epoch 32/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0577e-04 - root_mean_squared_error: 0.0103 - mae: 0.0079 - val_loss: 1.4849e-04 - val_root_mean_squared_error: 0.0122 - val_mae: 0.0097
# Epoch 33/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0169e-04 - root_mean_squared_error: 0.0101 - mae: 0.0076 - val_loss: 1.3826e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0092
# Epoch 34/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.0055e-04 - root_mean_squared_error: 0.0100 - mae: 0.0076 - val_loss: 1.4805e-04 - val_root_mean_squared_error: 0.0122 - val_mae: 0.0097
# Epoch 35/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0079e-04 - root_mean_squared_error: 0.0100 - mae: 0.0076 - val_loss: 1.5663e-04 - val_root_mean_squared_error: 0.0125 - val_mae: 0.0100
# Epoch 36/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0180e-04 - root_mean_squared_error: 0.0101 - mae: 0.0077 - val_loss: 1.7987e-04 - val_root_mean_squared_error: 0.0134 - val_mae: 0.0110
# Epoch 37/100
# 3/3 [==============================] - 0s 29ms/step - loss: 1.0467e-04 - root_mean_squared_error: 0.0102 - mae: 0.0078 - val_loss: 1.6774e-04 - val_root_mean_squared_error: 0.0130 - val_mae: 0.0105
# Epoch 38/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0131e-04 - root_mean_squared_error: 0.0101 - mae: 0.0076 - val_loss: 1.5457e-04 - val_root_mean_squared_error: 0.0124 - val_mae: 0.0100
# Epoch 39/100
# 3/3 [==============================] - 0s 19ms/step - loss: 9.9841e-05 - root_mean_squared_error: 0.0100 - mae: 0.0075 - val_loss: 1.5011e-04 - val_root_mean_squared_error: 0.0123 - val_mae: 0.0098
# Epoch 40/100
# 3/3 [==============================] - 0s 19ms/step - loss: 9.9645e-05 - root_mean_squared_error: 0.0100 - mae: 0.0075 - val_loss: 1.3921e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0093
# Epoch 41/100
# 3/3 [==============================] - 0s 17ms/step - loss: 9.8768e-05 - root_mean_squared_error: 0.0099 - mae: 0.0074 - val_loss: 1.3848e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0093
# Epoch 42/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.8609e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075 - val_loss: 1.3247e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0090
# Epoch 43/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.9065e-05 - root_mean_squared_error: 0.0100 - mae: 0.0075 - val_loss: 1.3879e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0093
# Epoch 44/100
# 3/3 [==============================] - 0s 17ms/step - loss: 9.8396e-05 - root_mean_squared_error: 0.0099 - mae: 0.0074 - val_loss: 1.2940e-04 - val_root_mean_squared_error: 0.0114 - val_mae: 0.0088
# Epoch 45/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0025e-04 - root_mean_squared_error: 0.0100 - mae: 0.0076 - val_loss: 1.2550e-04 - val_root_mean_squared_error: 0.0112 - val_mae: 0.0086
# Epoch 46/100
# 3/3 [==============================] - 0s 16ms/step - loss: 9.9600e-05 - root_mean_squared_error: 0.0100 - mae: 0.0075 - val_loss: 1.3961e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0094
# Epoch 47/100
# 3/3 [==============================] - 0s 17ms/step - loss: 9.8905e-05 - root_mean_squared_error: 0.0099 - mae: 0.0076 - val_loss: 1.5860e-04 - val_root_mean_squared_error: 0.0126 - val_mae: 0.0101
# Epoch 48/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0202e-04 - root_mean_squared_error: 0.0101 - mae: 0.0077 - val_loss: 1.4365e-04 - val_root_mean_squared_error: 0.0120 - val_mae: 0.0096
# Epoch 49/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.8227e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075 - val_loss: 1.2873e-04 - val_root_mean_squared_error: 0.0113 - val_mae: 0.0088
# Epoch 50/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.7727e-05 - root_mean_squared_error: 0.0099 - mae: 0.0074 - val_loss: 1.3089e-04 - val_root_mean_squared_error: 0.0114 - val_mae: 0.0090
# Epoch 51/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.7373e-05 - root_mean_squared_error: 0.0099 - mae: 0.0074 - val_loss: 1.4852e-04 - val_root_mean_squared_error: 0.0122 - val_mae: 0.0098
# Epoch 52/100
# 3/3 [==============================] - 0s 16ms/step - loss: 9.8113e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075 - val_loss: 1.4124e-04 - val_root_mean_squared_error: 0.0119 - val_mae: 0.0095
# Epoch 53/100
# 3/3 [==============================] - 0s 16ms/step - loss: 9.8296e-05 - root_mean_squared_error: 0.0099 - mae: 0.0074 - val_loss: 1.3242e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0091
# Epoch 54/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.8560e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075 - val_loss: 1.3494e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0092
# Epoch 55/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0268e-04 - root_mean_squared_error: 0.0101 - mae: 0.0074INFO:tensorflow:Assets written to: model_experiments/model_1_dense/assets
# 3/3 [==============================] - 1s 254ms/step - loss: 1.0010e-04 - root_mean_squared_error: 0.0100 - mae: 0.0076 - val_loss: 1.2333e-04 - val_root_mean_squared_error: 0.0111 - val_mae: 0.0086
# Epoch 56/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.0284e-04 - root_mean_squared_error: 0.0101 - mae: 0.0077 - val_loss: 1.2903e-04 - val_root_mean_squared_error: 0.0114 - val_mae: 0.0089
# Epoch 57/100
# 3/3 [==============================] - 0s 17ms/step - loss: 9.9101e-05 - root_mean_squared_error: 0.0100 - mae: 0.0075 - val_loss: 1.3211e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0091
# Epoch 58/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.8100e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075 - val_loss: 1.3452e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0092
# Epoch 59/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.7586e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075 - val_loss: 1.3206e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0091
# Epoch 60/100
# 3/3 [==============================] - 0s 22ms/step - loss: 9.7503e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075 - val_loss: 1.3448e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0092
# Epoch 61/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.7018e-05 - root_mean_squared_error: 0.0098 - mae: 0.0074 - val_loss: 1.3592e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0093
# Epoch 62/100
# 3/3 [==============================] - 0s 16ms/step - loss: 9.6437e-05 - root_mean_squared_error: 0.0098 - mae: 0.0074 - val_loss: 1.4674e-04 - val_root_mean_squared_error: 0.0121 - val_mae: 0.0097
# Epoch 63/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.8961e-05 - root_mean_squared_error: 0.0099 - mae: 0.0076 - val_loss: 1.3690e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0093
# Epoch 64/100
# 1/3 [=========>....................] - ETA: 0s - loss: 9.0199e-05 - root_mean_squared_error: 0.0095 - mae: 0.0069INFO:tensorflow:Assets written to: model_experiments/model_1_dense/assets
# 3/3 [==============================] - 1s 254ms/step - loss: 9.7056e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075 - val_loss: 1.2139e-04 - val_root_mean_squared_error: 0.0110 - val_mae: 0.0085
# Epoch 65/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.9813e-05 - root_mean_squared_error: 0.0100 - mae: 0.0076 - val_loss: 1.3178e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0091
# Epoch 66/100
# 3/3 [==============================] - 0s 17ms/step - loss: 9.6100e-05 - root_mean_squared_error: 0.0098 - mae: 0.0074 - val_loss: 1.5291e-04 - val_root_mean_squared_error: 0.0124 - val_mae: 0.0099
# Epoch 67/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.8694e-05 - root_mean_squared_error: 0.0099 - mae: 0.0076 - val_loss: 1.2607e-04 - val_root_mean_squared_error: 0.0112 - val_mae: 0.0088
# Epoch 68/100
# 1/3 [=========>....................] - ETA: 0s - loss: 9.0945e-05 - root_mean_squared_error: 0.0095 - mae: 0.0077INFO:tensorflow:Assets written to: model_experiments/model_1_dense/assets
# 3/3 [==============================] - 1s 249ms/step - loss: 1.0612e-04 - root_mean_squared_error: 0.0103 - mae: 0.0079 - val_loss: 1.1980e-04 - val_root_mean_squared_error: 0.0109 - val_mae: 0.0084
# Epoch 69/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0313e-04 - root_mean_squared_error: 0.0102 - mae: 0.0077 - val_loss: 1.7899e-04 - val_root_mean_squared_error: 0.0134 - val_mae: 0.0110
# Epoch 70/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1215e-04 - root_mean_squared_error: 0.0106 - mae: 0.0082 - val_loss: 2.1465e-04 - val_root_mean_squared_error: 0.0147 - val_mae: 0.0123
# Epoch 71/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1343e-04 - root_mean_squared_error: 0.0107 - mae: 0.0083 - val_loss: 1.3248e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0091
# Epoch 72/100
# 3/3 [==============================] - 0s 27ms/step - loss: 9.7581e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075 - val_loss: 1.1987e-04 - val_root_mean_squared_error: 0.0109 - val_mae: 0.0084
# Epoch 73/100
# 3/3 [==============================] - 0s 17ms/step - loss: 9.9613e-05 - root_mean_squared_error: 0.0100 - mae: 0.0076 - val_loss: 1.3524e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0092
# Epoch 74/100
# 3/3 [==============================] - 0s 17ms/step - loss: 9.6189e-05 - root_mean_squared_error: 0.0098 - mae: 0.0074 - val_loss: 1.3279e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0091
# Epoch 75/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.5266e-05 - root_mean_squared_error: 0.0098 - mae: 0.0074 - val_loss: 1.2013e-04 - val_root_mean_squared_error: 0.0110 - val_mae: 0.0084
# Epoch 76/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0048e-04 - root_mean_squared_error: 0.0100 - mae: 0.0076 - val_loss: 1.2035e-04 - val_root_mean_squared_error: 0.0110 - val_mae: 0.0084
# Epoch 77/100
# 3/3 [==============================] - 0s 16ms/step - loss: 9.7811e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075 - val_loss: 1.2483e-04 - val_root_mean_squared_error: 0.0112 - val_mae: 0.0087
# Epoch 78/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.5671e-05 - root_mean_squared_error: 0.0098 - mae: 0.0074 - val_loss: 1.2385e-04 - val_root_mean_squared_error: 0.0111 - val_mae: 0.0086
# Epoch 79/100
# 3/3 [==============================] - 0s 16ms/step - loss: 9.5641e-05 - root_mean_squared_error: 0.0098 - mae: 0.0074 - val_loss: 1.2137e-04 - val_root_mean_squared_error: 0.0110 - val_mae: 0.0085
# Epoch 80/100
# 1/3 [=========>....................] - ETA: 0s - loss: 8.6303e-05 - root_mean_squared_error: 0.0093 - mae: 0.0073INFO:tensorflow:Assets written to: model_experiments/model_1_dense/assets
# 3/3 [==============================] - 0s 244ms/step - loss: 9.8144e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075 - val_loss: 1.1956e-04 - val_root_mean_squared_error: 0.0109 - val_mae: 0.0084
# Epoch 81/100
# 3/3 [==============================] - 0s 14ms/step - loss: 9.7988e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075 - val_loss: 1.4025e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0095
# Epoch 82/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0116e-04 - root_mean_squared_error: 0.0101 - mae: 0.0078 - val_loss: 1.8903e-04 - val_root_mean_squared_error: 0.0137 - val_mae: 0.0114
# Epoch 83/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.1451e-04 - root_mean_squared_error: 0.0107 - mae: 0.0084 - val_loss: 1.7370e-04 - val_root_mean_squared_error: 0.0132 - val_mae: 0.0107
# Epoch 84/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1.0372e-04 - root_mean_squared_error: 0.0102 - mae: 0.0079 - val_loss: 1.2562e-04 - val_root_mean_squared_error: 0.0112 - val_mae: 0.0087
# Epoch 85/100
# 3/3 [==============================] - 0s 17ms/step - loss: 9.8658e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075 - val_loss: 1.2214e-04 - val_root_mean_squared_error: 0.0111 - val_mae: 0.0085
# Epoch 86/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.1199e-04 - root_mean_squared_error: 0.0106 - mae: 0.0081 - val_loss: 1.3396e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0092
# Epoch 87/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0528e-04 - root_mean_squared_error: 0.0103 - mae: 0.0079 - val_loss: 2.6999e-04 - val_root_mean_squared_error: 0.0164 - val_mae: 0.0141
# Epoch 88/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.4546e-04 - root_mean_squared_error: 0.0121 - mae: 0.0096 - val_loss: 1.7518e-04 - val_root_mean_squared_error: 0.0132 - val_mae: 0.0108
# Epoch 89/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0458e-04 - root_mean_squared_error: 0.0102 - mae: 0.0078 - val_loss: 1.2182e-04 - val_root_mean_squared_error: 0.0110 - val_mae: 0.0085
# Epoch 90/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.2249e-04 - root_mean_squared_error: 0.0111 - mae: 0.0090INFO:tensorflow:Assets written to: model_experiments/model_1_dense/assets
# 3/3 [==============================] - 1s 255ms/step - loss: 1.1736e-04 - root_mean_squared_error: 0.0108 - mae: 0.0084 - val_loss: 1.1793e-04 - val_root_mean_squared_error: 0.0109 - val_mae: 0.0083
# Epoch 91/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0319e-04 - root_mean_squared_error: 0.0102 - mae: 0.0077 - val_loss: 1.4473e-04 - val_root_mean_squared_error: 0.0120 - val_mae: 0.0096
# Epoch 92/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.6499e-05 - root_mean_squared_error: 0.0098 - mae: 0.0075 - val_loss: 1.5719e-04 - val_root_mean_squared_error: 0.0125 - val_mae: 0.0101
# Epoch 93/100
# 3/3 [==============================] - 0s 17ms/step - loss: 9.6736e-05 - root_mean_squared_error: 0.0098 - mae: 0.0075 - val_loss: 1.3379e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0092
# Epoch 94/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.4600e-05 - root_mean_squared_error: 0.0097 - mae: 0.0074 - val_loss: 1.2612e-04 - val_root_mean_squared_error: 0.0112 - val_mae: 0.0088
# Epoch 95/100
# 3/3 [==============================] - 0s 20ms/step - loss: 9.6430e-05 - root_mean_squared_error: 0.0098 - mae: 0.0074 - val_loss: 1.1936e-04 - val_root_mean_squared_error: 0.0109 - val_mae: 0.0084
# Epoch 96/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.9413e-05 - root_mean_squared_error: 0.0100 - mae: 0.0076 - val_loss: 1.1921e-04 - val_root_mean_squared_error: 0.0109 - val_mae: 0.0084
# Epoch 97/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0064e-04 - root_mean_squared_error: 0.0100 - mae: 0.0076 - val_loss: 1.2097e-04 - val_root_mean_squared_error: 0.0110 - val_mae: 0.0085
# Epoch 98/100
# 3/3 [==============================] - 0s 17ms/step - loss: 9.6086e-05 - root_mean_squared_error: 0.0098 - mae: 0.0074 - val_loss: 1.3450e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0093
# Epoch 99/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.5595e-05 - root_mean_squared_error: 0.0098 - mae: 0.0075 - val_loss: 1.3606e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0093
# Epoch 100/100
# 3/3 [==============================] - 0s 19ms/step - loss: 9.4177e-05 - root_mean_squared_error: 0.0097 - mae: 0.0074 - val_loss: 1.2643e-04 - val_root_mean_squared_error: 0.0112 - val_mae: 0.0089
# CPU times: user 14.1 s, sys: 384 ms, total: 14.5 s
# Wall time: 22.2 s

# %%
model_dnn.summary()
# Out:
# Model: "model_1_dense"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 128)               1024
#
#  dense_25 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 1,153
# Trainable params: 1,153
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.figure(figsize=(10,6))
plt.plot(history_1.history['loss'])
plt.plot(history_1.history['val_loss'])
plt.title('DNN model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(history_1.history['mae'])
plt.plot(history_1.history['val_mae'])
plt.title('DNN model')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(history_1.history['root_mean_squared_error'])
plt.plot(history_1.history['val_root_mean_squared_error'])
plt.title('DNN model')
plt.ylabel('rmse')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
model_dnn.evaluate(test_windows, test_labels)
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2643e-04 - root_mean_squared_error: 0.0112 - mae: 0.0089
# [0.00012642740330193192, 0.01124399434775114, 0.00885851215571165]

# %%
model_dnn = tf.keras.models.load_model("model_experiments/model_1_dense")
model_dnn.evaluate(test_windows, test_labels)
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1793e-04 - root_mean_squared_error: 0.0109 - mae: 0.0083
# [0.00011792969598900527, 0.010859544388949871, 0.00829827319830656]

# %%
def make_preds(model, input_data):
  """
  Uses model to make predictions on input_data.

  Parameters
  ----------
  model: trained model 
  input_data: windowed input data (same kind of data model was trained on)

  Returns model predictions on input_data.
  """
  forecast = model.predict(input_data)
  return tf.squeeze(forecast) # return 1D array of predictions

# %%
# Make predictions using model_dnn on the test dataset and view the results
model_dnn_preds = make_preds(model_dnn, test_windows)
len(model_dnn_preds), model_dnn_preds[:10]
# Out:
# (66, <tf.Tensor: shape=(10,), dtype=float32, numpy=
#  array([0.0472026 , 0.05441853, 0.0657307 , 0.06541698, 0.06328282,
#         0.06689076, 0.06101101, 0.06443907, 0.07323018, 0.06326975],
#        dtype=float32)>)

# %%
# Evaluate preds
model_dnn_results = evaluate_preds(y_true=tf.squeeze(test_labels), # reduce to right shape
                                 y_pred=model_dnn_preds)
model_dnn_results
# Out:
# {'mae': 0.008298273,
#  'mape': 13.82547,
#  'mase': 0.9150716,
#  'mse': 0.0001179297,
#  'rmse': 0.010859544}

# %%
plt.figure(figsize=(12,5))  
plt.plot(tf.squeeze(test_labels), color='blue', label='ET0 true')  
plt.plot(model_dnn_preds, color='red', label='ET0 predicted')  
plt.title('ET0 Forecasting')  
plt.xlabel('Date')  
plt.ylabel('ET0')  
plt.legend()
#plt.savefig("eto.png")
plt.show()

# %% [markdown]
# # Saving dnn model and applying transfer learning

# %%
model_dnn.save('dnn_model.h5')

# %%
loaded_model=tf.keras.models.load_model('dnn_model.h5')

# %%
loaded_model.layers
# Out:
# [<keras.layers.core.dense.Dense at 0x7fe70a4054d0>,
#  <keras.layers.core.dense.Dense at 0x7fe708907390>]

# %%
model1=Sequential()
for layer in loaded_model.layers[:-1]:
 model1.add(layer)
 
# Freeze all the layers of base model
for layer in loaded_model.layers:
 layer.trainable=False
 
# adding new layers

model1.add(Dense(32))
#model1.add(Dropout(0.2))
model1.add(Dense(1))

# %%
model1.build(input_shape=(None,7))

# %%
model1.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 128)               1024
#
#  dense_26 (Dense)            (None, 32)                4128
#
#  dense_27 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 5,185
# Trainable params: 4,161
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
rmse = tf.keras.metrics.RootMeanSquaredError()

# Compile model
model1.compile(loss="mean_squared_error",
                optimizer=tf.keras.optimizers.Adam(),
                metrics=[rmse,'mae'])

# %%
# %%time
history_2 = model1.fit(x=train_windows, # train windows of 7 timesteps of Bitcoin prices
              y=train_labels, # horizon value of 1 (using the previous 7 timesteps to predict next day)
              epochs=100,
              verbose=1,
              batch_size=128,
              validation_data=(test_windows, test_labels),
              callbacks=[create_model_checkpoint(model_name='loaded_model')])
# Out:
# Epoch 1/100
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0021 - root_mean_squared_error: 0.0460 - mae: 0.0425INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 369ms/step - loss: 0.0016 - root_mean_squared_error: 0.0401 - mae: 0.0360 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0329 - val_mae: 0.0310
# Epoch 2/100
# 1/3 [=========>....................] - ETA: 0s - loss: 2.4873e-04 - root_mean_squared_error: 0.0158 - mae: 0.0119INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 482ms/step - loss: 2.2258e-04 - root_mean_squared_error: 0.0149 - mae: 0.0117 - val_loss: 1.2751e-04 - val_root_mean_squared_error: 0.0113 - val_mae: 0.0084
# Epoch 3/100
# 3/3 [==============================] - 0s 15ms/step - loss: 4.4790e-04 - root_mean_squared_error: 0.0212 - mae: 0.0186 - val_loss: 1.2895e-04 - val_root_mean_squared_error: 0.0114 - val_mae: 0.0082
# Epoch 4/100
# 3/3 [==============================] - 0s 21ms/step - loss: 3.9893e-04 - root_mean_squared_error: 0.0200 - mae: 0.0174 - val_loss: 2.1308e-04 - val_root_mean_squared_error: 0.0146 - val_mae: 0.0124
# Epoch 5/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.8753e-04 - root_mean_squared_error: 0.0137 - mae: 0.0111 - val_loss: 5.7760e-04 - val_root_mean_squared_error: 0.0240 - val_mae: 0.0221
# Epoch 6/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.6951e-04 - root_mean_squared_error: 0.0130 - mae: 0.0102 - val_loss: 8.6768e-04 - val_root_mean_squared_error: 0.0295 - val_mae: 0.0276
# Epoch 7/100
# 3/3 [==============================] - 0s 19ms/step - loss: 2.1936e-04 - root_mean_squared_error: 0.0148 - mae: 0.0115 - val_loss: 6.7054e-04 - val_root_mean_squared_error: 0.0259 - val_mae: 0.0240
# Epoch 8/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.6579e-04 - root_mean_squared_error: 0.0129 - mae: 0.0100 - val_loss: 3.0231e-04 - val_root_mean_squared_error: 0.0174 - val_mae: 0.0153
# Epoch 9/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1.2676e-04 - root_mean_squared_error: 0.0113 - mae: 0.0087 - val_loss: 1.5128e-04 - val_root_mean_squared_error: 0.0123 - val_mae: 0.0100
# Epoch 10/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.5444e-04 - root_mean_squared_error: 0.0124 - mae: 0.0100 - val_loss: 1.3434e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0091
# Epoch 11/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.5059e-04 - root_mean_squared_error: 0.0123 - mae: 0.0099 - val_loss: 1.6195e-04 - val_root_mean_squared_error: 0.0127 - val_mae: 0.0105
# Epoch 12/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1879e-04 - root_mean_squared_error: 0.0109 - mae: 0.0085 - val_loss: 2.5146e-04 - val_root_mean_squared_error: 0.0159 - val_mae: 0.0137
# Epoch 13/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.1653e-04 - root_mean_squared_error: 0.0108 - mae: 0.0083 - val_loss: 3.0669e-04 - val_root_mean_squared_error: 0.0175 - val_mae: 0.0154
# Epoch 14/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.2586e-04 - root_mean_squared_error: 0.0112 - mae: 0.0087 - val_loss: 2.4810e-04 - val_root_mean_squared_error: 0.0158 - val_mae: 0.0136
# Epoch 15/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1.1329e-04 - root_mean_squared_error: 0.0106 - mae: 0.0082 - val_loss: 1.6699e-04 - val_root_mean_squared_error: 0.0129 - val_mae: 0.0107
# Epoch 16/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0786e-04 - root_mean_squared_error: 0.0104 - mae: 0.0079 - val_loss: 1.3635e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0092
# Epoch 17/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1.0986e-04 - root_mean_squared_error: 0.0105 - mae: 0.0081 - val_loss: 1.4749e-04 - val_root_mean_squared_error: 0.0121 - val_mae: 0.0098
# Epoch 18/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.0612e-04 - root_mean_squared_error: 0.0103 - mae: 0.0078 - val_loss: 1.5707e-04 - val_root_mean_squared_error: 0.0125 - val_mae: 0.0102
# Epoch 19/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0381e-04 - root_mean_squared_error: 0.0102 - mae: 0.0078 - val_loss: 1.3413e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0091
# Epoch 20/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0603e-04 - root_mean_squared_error: 0.0103 - mae: 0.0079 - val_loss: 1.2764e-04 - val_root_mean_squared_error: 0.0113 - val_mae: 0.0088
# Epoch 21/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0835e-04 - root_mean_squared_error: 0.0104 - mae: 0.0080 - val_loss: 1.2812e-04 - val_root_mean_squared_error: 0.0113 - val_mae: 0.0088
# Epoch 22/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0576e-04 - root_mean_squared_error: 0.0103 - mae: 0.0079 - val_loss: 1.3783e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0093
# Epoch 23/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0274e-04 - root_mean_squared_error: 0.0101 - mae: 0.0077 - val_loss: 1.6075e-04 - val_root_mean_squared_error: 0.0127 - val_mae: 0.0104
# Epoch 24/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0478e-04 - root_mean_squared_error: 0.0102 - mae: 0.0079 - val_loss: 1.7108e-04 - val_root_mean_squared_error: 0.0131 - val_mae: 0.0108
# Epoch 25/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0733e-04 - root_mean_squared_error: 0.0104 - mae: 0.0080 - val_loss: 1.5967e-04 - val_root_mean_squared_error: 0.0126 - val_mae: 0.0103
# Epoch 26/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0362e-04 - root_mean_squared_error: 0.0102 - mae: 0.0078 - val_loss: 1.2935e-04 - val_root_mean_squared_error: 0.0114 - val_mae: 0.0089
# Epoch 27/100
# 3/3 [==============================] - 0s 21ms/step - loss: 1.0325e-04 - root_mean_squared_error: 0.0102 - mae: 0.0077 - val_loss: 1.2924e-04 - val_root_mean_squared_error: 0.0114 - val_mae: 0.0085
# Epoch 28/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2380e-04 - root_mean_squared_error: 0.0111 - mae: 0.0086 - val_loss: 1.3872e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0089
# Epoch 29/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.2027e-04 - root_mean_squared_error: 0.0110 - mae: 0.0087INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 329ms/step - loss: 1.2627e-04 - root_mean_squared_error: 0.0112 - mae: 0.0087 - val_loss: 1.2459e-04 - val_root_mean_squared_error: 0.0112 - val_mae: 0.0084
# Epoch 30/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0786e-04 - root_mean_squared_error: 0.0104 - mae: 0.0079 - val_loss: 1.3243e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0091
# Epoch 31/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.0156e-04 - root_mean_squared_error: 0.0101 - mae: 0.0077 - val_loss: 1.7583e-04 - val_root_mean_squared_error: 0.0133 - val_mae: 0.0110
# Epoch 32/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1249e-04 - root_mean_squared_error: 0.0106 - mae: 0.0082 - val_loss: 1.7166e-04 - val_root_mean_squared_error: 0.0131 - val_mae: 0.0108
# Epoch 33/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0621e-04 - root_mean_squared_error: 0.0103 - mae: 0.0080 - val_loss: 1.3941e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0095
# Epoch 34/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.9039e-05 - root_mean_squared_error: 0.0100 - mae: 0.0076 - val_loss: 1.2972e-04 - val_root_mean_squared_error: 0.0114 - val_mae: 0.0090
# Epoch 35/100
# 3/3 [==============================] - 0s 20ms/step - loss: 1.0050e-04 - root_mean_squared_error: 0.0100 - mae: 0.0077 - val_loss: 1.3598e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0093
# Epoch 36/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.8923e-05 - root_mean_squared_error: 0.0099 - mae: 0.0076 - val_loss: 1.7312e-04 - val_root_mean_squared_error: 0.0132 - val_mae: 0.0109
# Epoch 37/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0366e-04 - root_mean_squared_error: 0.0102 - mae: 0.0078 - val_loss: 1.8063e-04 - val_root_mean_squared_error: 0.0134 - val_mae: 0.0112
# Epoch 38/100
# 3/3 [==============================] - 0s 19ms/step - loss: 1.0254e-04 - root_mean_squared_error: 0.0101 - mae: 0.0077 - val_loss: 1.5655e-04 - val_root_mean_squared_error: 0.0125 - val_mae: 0.0102
# Epoch 39/100
# 3/3 [==============================] - 0s 22ms/step - loss: 9.8612e-05 - root_mean_squared_error: 0.0099 - mae: 0.0076 - val_loss: 1.3938e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0095
# Epoch 40/100
# 3/3 [==============================] - 0s 20ms/step - loss: 9.8996e-05 - root_mean_squared_error: 0.0099 - mae: 0.0076 - val_loss: 1.3230e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0092
# Epoch 41/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.8382e-05 - root_mean_squared_error: 0.0099 - mae: 0.0076 - val_loss: 1.3772e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0094
# Epoch 42/100
# 3/3 [==============================] - 0s 19ms/step - loss: 9.7806e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075 - val_loss: 1.3627e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0093
# Epoch 43/100
# 3/3 [==============================] - 0s 25ms/step - loss: 9.7683e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075 - val_loss: 1.4355e-04 - val_root_mean_squared_error: 0.0120 - val_mae: 0.0097
# Epoch 44/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.7365e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075 - val_loss: 1.3264e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0092
# Epoch 45/100
# 1/3 [=========>....................] - ETA: 0s - loss: 8.7141e-05 - root_mean_squared_error: 0.0093 - mae: 0.0072INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 349ms/step - loss: 9.8644e-05 - root_mean_squared_error: 0.0099 - mae: 0.0076 - val_loss: 1.2374e-04 - val_root_mean_squared_error: 0.0111 - val_mae: 0.0087
# Epoch 46/100
# 3/3 [==============================] - 0s 21ms/step - loss: 9.9157e-05 - root_mean_squared_error: 0.0100 - mae: 0.0077 - val_loss: 1.3533e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0093
# Epoch 47/100
# 3/3 [==============================] - 0s 19ms/step - loss: 9.7379e-05 - root_mean_squared_error: 0.0099 - mae: 0.0075 - val_loss: 1.6623e-04 - val_root_mean_squared_error: 0.0129 - val_mae: 0.0106
# Epoch 48/100
# 3/3 [==============================] - 0s 22ms/step - loss: 1.0155e-04 - root_mean_squared_error: 0.0101 - mae: 0.0077 - val_loss: 1.6345e-04 - val_root_mean_squared_error: 0.0128 - val_mae: 0.0105
# Epoch 49/100
# 3/3 [==============================] - 0s 24ms/step - loss: 9.9522e-05 - root_mean_squared_error: 0.0100 - mae: 0.0076 - val_loss: 1.3711e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0094
# Epoch 50/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.5839e-05 - root_mean_squared_error: 0.0098 - mae: 0.0074 - val_loss: 1.2650e-04 - val_root_mean_squared_error: 0.0112 - val_mae: 0.0089
# Epoch 51/100
# 3/3 [==============================] - 0s 19ms/step - loss: 9.6838e-05 - root_mean_squared_error: 0.0098 - mae: 0.0075 - val_loss: 1.3425e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0093
# Epoch 52/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.6065e-05 - root_mean_squared_error: 0.0098 - mae: 0.0074 - val_loss: 1.3749e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0095
# Epoch 53/100
# 3/3 [==============================] - 0s 19ms/step - loss: 9.6366e-05 - root_mean_squared_error: 0.0098 - mae: 0.0075 - val_loss: 1.3761e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0095
# Epoch 54/100
# 3/3 [==============================] - 0s 20ms/step - loss: 9.6319e-05 - root_mean_squared_error: 0.0098 - mae: 0.0075 - val_loss: 1.3393e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0093
# Epoch 55/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0224e-04 - root_mean_squared_error: 0.0101 - mae: 0.0076INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 351ms/step - loss: 9.8464e-05 - root_mean_squared_error: 0.0099 - mae: 0.0076 - val_loss: 1.2013e-04 - val_root_mean_squared_error: 0.0110 - val_mae: 0.0086
# Epoch 56/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.0096e-04 - root_mean_squared_error: 0.0100 - mae: 0.0078 - val_loss: 1.2448e-04 - val_root_mean_squared_error: 0.0112 - val_mae: 0.0088
# Epoch 57/100
# 3/3 [==============================] - 0s 21ms/step - loss: 9.8303e-05 - root_mean_squared_error: 0.0099 - mae: 0.0076 - val_loss: 1.2733e-04 - val_root_mean_squared_error: 0.0113 - val_mae: 0.0090
# Epoch 58/100
# 3/3 [==============================] - 0s 20ms/step - loss: 9.7109e-05 - root_mean_squared_error: 0.0099 - mae: 0.0076 - val_loss: 1.3134e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0092
# Epoch 59/100
# 3/3 [==============================] - 0s 19ms/step - loss: 9.6134e-05 - root_mean_squared_error: 0.0098 - mae: 0.0075 - val_loss: 1.3474e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0093
# Epoch 60/100
# 3/3 [==============================] - 0s 20ms/step - loss: 9.5302e-05 - root_mean_squared_error: 0.0098 - mae: 0.0074 - val_loss: 1.3999e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0096
# Epoch 61/100
# 3/3 [==============================] - 0s 19ms/step - loss: 9.5042e-05 - root_mean_squared_error: 0.0097 - mae: 0.0074 - val_loss: 1.3449e-04 - val_root_mean_squared_error: 0.0116 - val_mae: 0.0093
# Epoch 62/100
# 3/3 [==============================] - 0s 30ms/step - loss: 9.5019e-05 - root_mean_squared_error: 0.0097 - mae: 0.0074 - val_loss: 1.4239e-04 - val_root_mean_squared_error: 0.0119 - val_mae: 0.0097
# Epoch 63/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.6754e-05 - root_mean_squared_error: 0.0098 - mae: 0.0075 - val_loss: 1.4664e-04 - val_root_mean_squared_error: 0.0121 - val_mae: 0.0098
# Epoch 64/100
# 3/3 [==============================] - 0s 16ms/step - loss: 9.5424e-05 - root_mean_squared_error: 0.0098 - mae: 0.0075 - val_loss: 1.2615e-04 - val_root_mean_squared_error: 0.0112 - val_mae: 0.0089
# Epoch 65/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.5177e-05 - root_mean_squared_error: 0.0098 - mae: 0.0074 - val_loss: 1.2711e-04 - val_root_mean_squared_error: 0.0113 - val_mae: 0.0090
# Epoch 66/100
# 3/3 [==============================] - 0s 17ms/step - loss: 9.4947e-05 - root_mean_squared_error: 0.0097 - mae: 0.0074 - val_loss: 1.3708e-04 - val_root_mean_squared_error: 0.0117 - val_mae: 0.0094
# Epoch 67/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.5001e-05 - root_mean_squared_error: 0.0097 - mae: 0.0074 - val_loss: 1.3193e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0092
# Epoch 68/100
# 1/3 [=========>....................] - ETA: 0s - loss: 9.0831e-05 - root_mean_squared_error: 0.0095 - mae: 0.0076INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 311ms/step - loss: 9.8366e-05 - root_mean_squared_error: 0.0099 - mae: 0.0076 - val_loss: 1.1904e-04 - val_root_mean_squared_error: 0.0109 - val_mae: 0.0085
# Epoch 69/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.6675e-05 - root_mean_squared_error: 0.0098 - mae: 0.0075 - val_loss: 1.6443e-04 - val_root_mean_squared_error: 0.0128 - val_mae: 0.0105
# Epoch 70/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0173e-04 - root_mean_squared_error: 0.0101 - mae: 0.0078 - val_loss: 1.9640e-04 - val_root_mean_squared_error: 0.0140 - val_mae: 0.0118
# Epoch 71/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0458e-04 - root_mean_squared_error: 0.0102 - mae: 0.0079 - val_loss: 1.4105e-04 - val_root_mean_squared_error: 0.0119 - val_mae: 0.0096
# Epoch 72/100
# 3/3 [==============================] - 0s 16ms/step - loss: 9.4362e-05 - root_mean_squared_error: 0.0097 - mae: 0.0074 - val_loss: 1.1911e-04 - val_root_mean_squared_error: 0.0109 - val_mae: 0.0085
# Epoch 73/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.5657e-05 - root_mean_squared_error: 0.0098 - mae: 0.0075 - val_loss: 1.2737e-04 - val_root_mean_squared_error: 0.0113 - val_mae: 0.0090
# Epoch 74/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.3931e-05 - root_mean_squared_error: 0.0097 - mae: 0.0073 - val_loss: 1.2854e-04 - val_root_mean_squared_error: 0.0113 - val_mae: 0.0090
# Epoch 75/100
# 1/3 [=========>....................] - ETA: 0s - loss: 8.7679e-05 - root_mean_squared_error: 0.0094 - mae: 0.0072INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 314ms/step - loss: 9.3639e-05 - root_mean_squared_error: 0.0097 - mae: 0.0073 - val_loss: 1.1817e-04 - val_root_mean_squared_error: 0.0109 - val_mae: 0.0084
# Epoch 76/100
# 1/3 [=========>....................] - ETA: 0s - loss: 8.9531e-05 - root_mean_squared_error: 0.0095 - mae: 0.0073INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 306ms/step - loss: 9.6218e-05 - root_mean_squared_error: 0.0098 - mae: 0.0075 - val_loss: 1.1636e-04 - val_root_mean_squared_error: 0.0108 - val_mae: 0.0083
# Epoch 77/100
# 3/3 [==============================] - 0s 16ms/step - loss: 9.5821e-05 - root_mean_squared_error: 0.0098 - mae: 0.0075 - val_loss: 1.2068e-04 - val_root_mean_squared_error: 0.0110 - val_mae: 0.0086
# Epoch 78/100
# 3/3 [==============================] - 0s 17ms/step - loss: 9.4296e-05 - root_mean_squared_error: 0.0097 - mae: 0.0074 - val_loss: 1.2356e-04 - val_root_mean_squared_error: 0.0111 - val_mae: 0.0088
# Epoch 79/100
# 3/3 [==============================] - 0s 16ms/step - loss: 9.3686e-05 - root_mean_squared_error: 0.0097 - mae: 0.0073 - val_loss: 1.1954e-04 - val_root_mean_squared_error: 0.0109 - val_mae: 0.0085
# Epoch 80/100
# 1/3 [=========>....................] - ETA: 0s - loss: 8.3898e-05 - root_mean_squared_error: 0.0092 - mae: 0.0071INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 310ms/step - loss: 9.5679e-05 - root_mean_squared_error: 0.0098 - mae: 0.0075 - val_loss: 1.1355e-04 - val_root_mean_squared_error: 0.0107 - val_mae: 0.0080
# Epoch 81/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.8066e-05 - root_mean_squared_error: 0.0099 - mae: 0.0076 - val_loss: 1.3139e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0092
# Epoch 82/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.7314e-05 - root_mean_squared_error: 0.0099 - mae: 0.0076 - val_loss: 1.9289e-04 - val_root_mean_squared_error: 0.0139 - val_mae: 0.0116
# Epoch 83/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.1206e-04 - root_mean_squared_error: 0.0106 - mae: 0.0083 - val_loss: 1.8783e-04 - val_root_mean_squared_error: 0.0137 - val_mae: 0.0114
# Epoch 84/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0503e-04 - root_mean_squared_error: 0.0102 - mae: 0.0079 - val_loss: 1.2578e-04 - val_root_mean_squared_error: 0.0112 - val_mae: 0.0089
# Epoch 85/100
# 3/3 [==============================] - 0s 27ms/step - loss: 9.5671e-05 - root_mean_squared_error: 0.0098 - mae: 0.0075 - val_loss: 1.1574e-04 - val_root_mean_squared_error: 0.0108 - val_mae: 0.0081
# Epoch 86/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.1266e-04 - root_mean_squared_error: 0.0106 - mae: 0.0082 - val_loss: 1.2629e-04 - val_root_mean_squared_error: 0.0112 - val_mae: 0.0089
# Epoch 87/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0271e-04 - root_mean_squared_error: 0.0101 - mae: 0.0077 - val_loss: 2.9060e-04 - val_root_mean_squared_error: 0.0170 - val_mae: 0.0147
# Epoch 88/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.4794e-04 - root_mean_squared_error: 0.0122 - mae: 0.0098 - val_loss: 1.9087e-04 - val_root_mean_squared_error: 0.0138 - val_mae: 0.0115
# Epoch 89/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0484e-04 - root_mean_squared_error: 0.0102 - mae: 0.0079 - val_loss: 1.1433e-04 - val_root_mean_squared_error: 0.0107 - val_mae: 0.0081
# Epoch 90/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.2388e-04 - root_mean_squared_error: 0.0111 - mae: 0.0090INFO:tensorflow:Assets written to: model_experiments/loaded_model/assets
# 3/3 [==============================] - 1s 305ms/step - loss: 1.1662e-04 - root_mean_squared_error: 0.0108 - mae: 0.0084 - val_loss: 1.1158e-04 - val_root_mean_squared_error: 0.0106 - val_mae: 0.0079
# Epoch 91/100
# 3/3 [==============================] - 0s 14ms/step - loss: 1.0417e-04 - root_mean_squared_error: 0.0102 - mae: 0.0079 - val_loss: 1.4643e-04 - val_root_mean_squared_error: 0.0121 - val_mae: 0.0098
# Epoch 92/100
# 3/3 [==============================] - 0s 18ms/step - loss: 9.4931e-05 - root_mean_squared_error: 0.0097 - mae: 0.0075 - val_loss: 1.7613e-04 - val_root_mean_squared_error: 0.0133 - val_mae: 0.0110
# Epoch 93/100
# 3/3 [==============================] - 0s 17ms/step - loss: 9.7347e-05 - root_mean_squared_error: 0.0099 - mae: 0.0076 - val_loss: 1.4230e-04 - val_root_mean_squared_error: 0.0119 - val_mae: 0.0097
# Epoch 94/100
# 3/3 [==============================] - 0s 15ms/step - loss: 9.2626e-05 - root_mean_squared_error: 0.0096 - mae: 0.0073 - val_loss: 1.2383e-04 - val_root_mean_squared_error: 0.0111 - val_mae: 0.0089
# Epoch 95/100
# 3/3 [==============================] - 0s 19ms/step - loss: 9.4871e-05 - root_mean_squared_error: 0.0097 - mae: 0.0075 - val_loss: 1.1248e-04 - val_root_mean_squared_error: 0.0106 - val_mae: 0.0081
# Epoch 96/100
# 3/3 [==============================] - 0s 15ms/step - loss: 1.0004e-04 - root_mean_squared_error: 0.0100 - mae: 0.0077 - val_loss: 1.1331e-04 - val_root_mean_squared_error: 0.0106 - val_mae: 0.0081
# Epoch 97/100
# 3/3 [==============================] - 0s 16ms/step - loss: 9.8334e-05 - root_mean_squared_error: 0.0099 - mae: 0.0076 - val_loss: 1.1985e-04 - val_root_mean_squared_error: 0.0109 - val_mae: 0.0086
# Epoch 98/100
# 3/3 [==============================] - 0s 16ms/step - loss: 9.3296e-05 - root_mean_squared_error: 0.0097 - mae: 0.0073 - val_loss: 1.3826e-04 - val_root_mean_squared_error: 0.0118 - val_mae: 0.0095
# Epoch 99/100
# 3/3 [==============================] - 0s 16ms/step - loss: 9.4219e-05 - root_mean_squared_error: 0.0097 - mae: 0.0074 - val_loss: 1.3305e-04 - val_root_mean_squared_error: 0.0115 - val_mae: 0.0093
# Epoch 100/100
# 3/3 [==============================] - 0s 17ms/step - loss: 9.2285e-05 - root_mean_squared_error: 0.0096 - mae: 0.0073 - val_loss: 1.2337e-04 - val_root_mean_squared_error: 0.0111 - val_mae: 0.0088
# CPU times: user 11.5 s, sys: 380 ms, total: 11.9 s
# Wall time: 20.9 s

# %%
plt.figure(figsize=(10,6))
plt.plot(history_2.history['loss'])
plt.plot(history_2.history['val_loss'])
plt.title('pretrained DNN model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(history_2.history['mae'])
plt.plot(history_2.history['val_mae'])
plt.title('pretrained DNN model')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(history_2.history['root_mean_squared_error'])
plt.plot(history_2.history['val_root_mean_squared_error'])
plt.title('pretrained DNN model')
plt.ylabel('rmse')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
model_dnn_transfer = tf.keras.models.load_model("model_experiments/loaded_model")
model_dnn_transfer.evaluate(test_windows, test_labels)
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1158e-04 - root_mean_squared_error: 0.0106 - mae: 0.0079
# [0.00011157913831993937, 0.010563102550804615, 0.007907181046903133]

# %%
model_dnn_preds = make_preds(model_dnn_transfer, test_windows)
len(model_dnn_preds), model_dnn_preds[:10]
# Out:
# (66, <tf.Tensor: shape=(10,), dtype=float32, numpy=
#  array([0.04697133, 0.05552708, 0.06642628, 0.06464104, 0.06431028,
#         0.066613  , 0.0614359 , 0.06690089, 0.07458316, 0.0617387 ],
#        dtype=float32)>)

# %%
model_dnn_results = evaluate_preds(y_true=tf.squeeze(test_labels), # reduce to right shape
                                 y_pred=model_dnn_preds)
model_dnn_results
# Out:
# {'mae': 0.007907181,
#  'mape': 13.236204,
#  'mase': 0.87194484,
#  'mse': 0.00011157915,
#  'rmse': 0.0105631035}

# %%
plt.figure(figsize=(12,5))  
plt.plot(tf.squeeze(test_labels), color='blue', label='ET0 true')  
plt.plot(model_dnn_preds, color='red', label='ET0 predicted')  
plt.title('ET0 Forecasting')  
plt.xlabel('Date')  
plt.ylabel('ET0')  
plt.legend()
#plt.savefig("eto.png")
plt.show()

# %%
barWidth = 0.20
fig = plt.subplots(figsize =(8, 10))
 
# set height of bar
total_time = [14.5, 11.9]
wall_time = [22.2, 20.9]

 
# Set position of bar on X axis
br1 = np.arange(len(total_time))
br2 = [x + barWidth for x in br1]
 
# Make the plot
plt.bar(br1, total_time, color ='r', width = barWidth,
        edgecolor ='grey', label ='Total Time')
plt.bar(br2, wall_time, color ='g', width = barWidth,
        edgecolor ='grey', label ='Wall Time')
 
# Adding Xticks
plt.xlabel('models', fontweight ='bold', fontsize = 15)
plt.ylabel('time', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(total_time))],
        ['DNN model', 'pretrained DNN model'])
 
plt.legend()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x = ['Total Time', 'Wall Time']
time = [14.5,22.2]
ax.bar(x,time,color='r')
plt.title('DNN model')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x = ['Total Time', 'Wall Time']
time = [11.9,20.9]
ax.bar(x,time,color='g')
plt.title('Pretrained DNN model')
plt.show()
